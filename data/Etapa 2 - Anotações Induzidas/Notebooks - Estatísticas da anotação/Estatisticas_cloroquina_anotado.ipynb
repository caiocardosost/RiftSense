# %% [markdown]
# # **Projeto de Graduação em Computação II [2026-Q1]**
#
# Universidade Federal do ABC
#
# Orientador Carlos da Silva dos Santos

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# Caio Cardoso Dos Santos - RA: 11202021632
#
# Victor Ravazio de Lima - RA: 11201920941

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %%
# modulo para importar dataset a partir de um link
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
#Bibliotecas
import pandas as pd
import numpy as np
from google.colab import files
import gdown
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
#Variaveis de controle
anotado = 300
# num_replys_anotados = 150
# num_quotes_anotados = 150
# num_originals_anotados = 150

# %%
# baixando dataset para o collab
import gdown

file_class_caio = "1lM2oD3feMLsXeX-i6LqAtj3_syH-Swuu"
file_class_victor = "1FQQ9t-tGo04dIJ6LSGN3fesM2SU6GNrf"
url_1 = f"https://drive.google.com/uc?id={file_class_caio}"
url_2 = f"https://drive.google.com/uc?id={file_class_victor}"

gdown.download(url_1, "cloroquina_anotado_caio.csv", quiet=False)
gdown.download(url_2, "cloroquina_anotado_victor.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1lM2oD3feMLsXeX-i6LqAtj3_syH-Swuu
# To: /content/cloroquina_anotado_caio.csv
# 100%|██████████| 12.4M/12.4M [00:00<00:00, 43.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FQQ9t-tGo04dIJ6LSGN3fesM2SU6GNrf
# To: /content/cloroquina_anotado_victor.csv
# 100%|██████████| 12.4M/12.4M [00:00<00:00, 49.8MB/s]
# 'cloroquina_anotado_victor.csv'

# %%
#carregando o dataset
df_caio = pd.read_csv ("cloroquina_anotado_caio.csv")
df_victor = pd.read_csv ("cloroquina_anotado_victor.csv")

# %%
#numero total de instancias no dataset
df_caio.shape
# Out:
# (42907, 6)

# %%
#numero total de instancias no dataset
df_victor.shape
# Out:
# (42907, 6)

# %%
df_caio.head(20)
# Out:
#                                               tweet_1  \
# 0   Bolsonaro finalmente conseguiu forçar o Min. d...
# 1   - Ainda não existe comprovação científica, mas...
# 2   Bolsonaro finalmente conseguiu forçar o Min. d...
# 3   - Ainda não existe comprovação científica, mas...
# 4   - Ainda não existe comprovação científica, mas...
# 5   Bolsonaro finalmente conseguiu forçar o Min. d...
# 6   Quer dar placebo pro povo? Dê, não tem problem...
# 7   - Ainda não existe comprovação científica, mas...
# 8   - Ainda não existe comprovação científica, mas...
# 9   Bolsonaro finalmente conseguiu forçar o Min. d...
# 10  - Ainda não existe comprovação científica, mas...
# 11  Bolsonaro finalmente conseguiu forçar o Min. d...
# 12  - Ainda não existe comprovação científica, mas...
# 13  hahaha.  Amigo, meus parentes são médicos. Não...
# 14  - Ainda não existe comprovação científica, mas...
# 15  Bolsonaro finalmente conseguiu forçar o Min. d...
# 16  Bolsonaro queria mudar a bula do remédio, não ...
# 17  Apresentei um projeto de decreto legislativo p...
# 18  - Ainda não existe comprovação científica, mas...
# 19  Apresentei um projeto de decreto legislativo p...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1   Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2   Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3   vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4   "Não existe comprovação científica" Porra pres...      2       0.030527
# 5   É só não tomar... Todo este discurso murcha qu...      1       0.030933
# 6   Ta ligado que o Curitiba é uma das cidades com...      1       0.032048
# 7         foco no “não existe comprovação científica”      2       0.033538
# 8   Presta atenção no "NÃO EXISTE  COMPROVAÇÃO CIE...      2       0.033968
# 9   A cloroquina existe desde 1955.2 meses atrás e...      1       0.034570
# 10  Kkk como pode (não tem comprovação)e ridículo ...      1       0.034924
# 11  Só em tu ser contra isso mostra que a cloroqui...      1       0.036299
# 12  ...quando se fala em saúde todo e qualquer pro...      1       0.036345
# 13  Seguidor de Olavo? Cara, você tá louco!  Já pa...      1       0.042833
# 14  O pior é estar em guerra e mandar um soldado n...      1       0.043668
# 15  Quem for de direita toma cloroquina quem for d...      1       0.048783
# 16  Narrativa imunda é o que vcs fazem nesse jorna...      1       0.049233
# 17  O Sr. não tem vergonha de politizar algo tão s...      1       0.049860
# 18  AINDA NÃO EXISTE COMPROVAÇÃO CIENTÍFICA, MAS A...      2       0.052811
# 19  Vc é um lixo!! Quem faz uso político da cloroq...      1       0.053285
#
#     P(Conflict)  Conflict
# 0      0.976709       1.0
# 1      0.971572       1.0
# 2      0.970327       1.0
# 3      0.969569       1.0
# 4      0.969473       1.0
# 5      0.969067       1.0
# 6      0.967952       1.0
# 7      0.966462       1.0
# 8      0.966032       1.0
# 9      0.965430       1.0
# 10     0.965076       1.0
# 11     0.963701       1.0
# 12     0.963655       1.0
# 13     0.957167       1.0
# 14     0.956332       1.0
# 15     0.951217       1.0
# 16     0.950767       1.0
# 17     0.950140       1.0
# 18     0.947189       1.0
# 19     0.946715       1.0

# %%
df_victor.head(20)
# Out:
#                                               tweet_1  \
# 0   Bolsonaro finalmente conseguiu forçar o Min. d...
# 1   - Ainda não existe comprovação científica, mas...
# 2   Bolsonaro finalmente conseguiu forçar o Min. d...
# 3   - Ainda não existe comprovação científica, mas...
# 4   - Ainda não existe comprovação científica, mas...
# 5   Bolsonaro finalmente conseguiu forçar o Min. d...
# 6   Quer dar placebo pro povo? Dê, não tem problem...
# 7   - Ainda não existe comprovação científica, mas...
# 8   - Ainda não existe comprovação científica, mas...
# 9   Bolsonaro finalmente conseguiu forçar o Min. d...
# 10  - Ainda não existe comprovação científica, mas...
# 11  Bolsonaro finalmente conseguiu forçar o Min. d...
# 12  - Ainda não existe comprovação científica, mas...
# 13  hahaha.  Amigo, meus parentes são médicos. Não...
# 14  - Ainda não existe comprovação científica, mas...
# 15  Bolsonaro finalmente conseguiu forçar o Min. d...
# 16  Bolsonaro queria mudar a bula do remédio, não ...
# 17  Apresentei um projeto de decreto legislativo p...
# 18  - Ainda não existe comprovação científica, mas...
# 19  Apresentei um projeto de decreto legislativo p...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1   Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2   Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3   vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4   "Não existe comprovação científica" Porra pres...      2       0.030527
# 5   É só não tomar... Todo este discurso murcha qu...      1       0.030933
# 6   Ta ligado que o Curitiba é uma das cidades com...      1       0.032048
# 7         foco no “não existe comprovação científica”      2       0.033538
# 8   Presta atenção no "NÃO EXISTE  COMPROVAÇÃO CIE...      2       0.033968
# 9   A cloroquina existe desde 1955.2 meses atrás e...      1       0.034570
# 10  Kkk como pode (não tem comprovação)e ridículo ...      1       0.034924
# 11  Só em tu ser contra isso mostra que a cloroqui...      1       0.036299
# 12  ...quando se fala em saúde todo e qualquer pro...      1       0.036345
# 13  Seguidor de Olavo? Cara, você tá louco!  Já pa...      1       0.042833
# 14  O pior é estar em guerra e mandar um soldado n...      1       0.043668
# 15  Quem for de direita toma cloroquina quem for d...      1       0.048783
# 16  Narrativa imunda é o que vcs fazem nesse jorna...      1       0.049233
# 17  O Sr. não tem vergonha de politizar algo tão s...      1       0.049860
# 18  AINDA NÃO EXISTE COMPROVAÇÃO CIENTÍFICA, MAS A...      2       0.052811
# 19  Vc é um lixo!! Quem faz uso político da cloroq...      1       0.053285
#
#     P(Conflict)  Conflict
# 0      0.976709       1.0
# 1      0.971572       1.0
# 2      0.970327       1.0
# 3      0.969569       1.0
# 4      0.969473       1.0
# 5      0.969067       1.0
# 6      0.967952       1.0
# 7      0.966462       1.0
# 8      0.966032       1.0
# 9      0.965430       1.0
# 10     0.965076       1.0
# 11     0.963701       1.0
# 12     0.963655       1.0
# 13     0.957167       1.0
# 14     0.956332       1.0
# 15     0.951217       1.0
# 16     0.950767       1.0
# 17     0.950140       1.0
# 18     0.947189       1.0
# 19     0.946715       1.0

# %% [markdown]
# # **Analise Exploratória**

# %%
# restrigindo por quantidade anotada
df_caio = df_caio.iloc[:anotado,:]
df_caio['Conflict'] = df_caio['Conflict'].astype(int) #convertendo valores para inteiros
df_victor = df_victor.iloc[:anotado,:]
df_victor['Conflict'] = df_victor['Conflict'].astype(int)

# %%
#separando por classe

# %%
df_caio
# Out:
#                                                tweet_1  \
# 0    Bolsonaro finalmente conseguiu forçar o Min. d...
# 1    - Ainda não existe comprovação científica, mas...
# 2    Bolsonaro finalmente conseguiu forçar o Min. d...
# 3    - Ainda não existe comprovação científica, mas...
# 4    - Ainda não existe comprovação científica, mas...
# ..                                                 ...
# 295  Bolsonaro finalmente conseguiu forçar o Min. d...
# 296  Aos que apoiam a cloroquina, a tubaína ou o co...
# 297  - Ainda não existe comprovação científica, mas...
# 298  Além dos efeitos colaterais graves da cloroqui...
# 299  Bolsonaro admite que não há comprovação cientí...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1    Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2    Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3    vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4    "Não existe comprovação científica" Porra pres...      2       0.030527
# ..                                                 ...    ...            ...
# 295  A que ponto nós chegamos? Ninguém vai parar es...      2       0.061278
# 296  Antes a religião se opunha a ciência , hoje é ...      2       0.061418
# 297  Faça um pronunciamento em rede nacional mostra...      1       0.061510
# 298  Você sabe que o estudo de Manaus com pesquisad...      1       0.061512
# 299  Queria saber tb se há comprovação científica q...      2       0.061530
#
#      P(Conflict)  Conflict
# 0       0.976709         1
# 1       0.971572         1
# 2       0.970327         1
# 3       0.969569         1
# 4       0.969473         1
# ..           ...       ...
# 295     0.938722         0
# 296     0.938582         0
# 297     0.938490         0
# 298     0.938488         1
# 299     0.938470         0
#
# [300 rows x 6 columns]

# %%
df_victor
# Out:
#                                                tweet_1  \
# 0    Bolsonaro finalmente conseguiu forçar o Min. d...
# 1    - Ainda não existe comprovação científica, mas...
# 2    Bolsonaro finalmente conseguiu forçar o Min. d...
# 3    - Ainda não existe comprovação científica, mas...
# 4    - Ainda não existe comprovação científica, mas...
# ..                                                 ...
# 295  Bolsonaro finalmente conseguiu forçar o Min. d...
# 296  Aos que apoiam a cloroquina, a tubaína ou o co...
# 297  - Ainda não existe comprovação científica, mas...
# 298  Além dos efeitos colaterais graves da cloroqui...
# 299  Bolsonaro admite que não há comprovação cientí...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1    Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2    Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3    vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4    "Não existe comprovação científica" Porra pres...      2       0.030527
# ..                                                 ...    ...            ...
# 295  A que ponto nós chegamos? Ninguém vai parar es...      2       0.061278
# 296  Antes a religião se opunha a ciência , hoje é ...      2       0.061418
# 297  Faça um pronunciamento em rede nacional mostra...      1       0.061510
# 298  Você sabe que o estudo de Manaus com pesquisad...      1       0.061512
# 299  Queria saber tb se há comprovação científica q...      2       0.061530
#
#      P(Conflict)  Conflict
# 0       0.976709         1
# 1       0.971572         1
# 2       0.970327         1
# 3       0.969569         1
# 4       0.969473         1
# ..           ...       ...
# 295     0.938722         0
# 296     0.938582         0
# 297     0.938490         0
# 298     0.938488         1
# 299     0.938470         0
#
# [300 rows x 6 columns]

# %%
confusion = np.zeros((3,3))

idx_diff = []  # lista com os índices i onde as classificações diferem

# %%
for i in range(df_caio.shape[0]):
  caio = int(df_caio.iloc[i]["Conflict"])
  victor = int(df_victor.iloc[i]["Conflict"])

  # mapeia -1 para 2 para a matriz 3x3
  row = 2 if caio == -1 else caio
  col = 2 if victor == -1 else victor

  confusion[row][col] += 1

  # se são diferentes (fora da diagonal principal)
  if row != col:
    idx_diff.append(i)

# %%
confusion
# Out:
# array([[126.,  19.,   1.],
#        [  7., 133.,   1.],
#        [  3.,   6.,   4.]])

# %%
idx_diff
# Out:
# [23,
#  24,
#  26,
#  29,
#  32,
#  35,
#  41,
#  54,
#  62,
#  72,
#  76,
#  81,
#  87,
#  88,
#  92,
#  104,
#  107,
#  109,
#  119,
#  128,
#  130,
#  159,
#  170,
#  172,
#  175,
#  183,
#  186,
#  188,
#  194,
#  198,
#  199,
#  214,
#  221,
#  256,
#  257,
#  258,
#  283]

# %%
labels = ["0", "1", "-1"] # classes

plt.figure(figsize=(6,5))
sns.heatmap(confusion, annot=True, fmt=".0f", cmap="Blues", xticklabels=labels, yticklabels=labels) #desenha a matriz de confusão como uma "matriz de calor"

plt.xlabel("Predição Victor")
plt.ylabel("Predição Caio")
plt.title("Matriz de Confusão - Predição Pares")
plt.show()

# %%
mapa = {-1: "Indeterminado", 0: "Não Conflito", 1: "Conflito"}
mapa_tipo = {0: "Genérico", 1: "Reply", 2: "Quote"}

for i in range(len(idx_diff)):
  print("Tipo: ", mapa_tipo[int(df_caio.loc[idx_diff[i], "Class"])])
  print("Tweet 1: ", df_caio.loc[idx_diff[i], "tweet_1"])
  print("Tweet 2: ", df_caio.loc[idx_diff[i], "tweet_2"])
  print("Classificação Caio: ", mapa[int(df_caio.loc[idx_diff[i], "Conflict"])])
  print("Classificação Victor: ", mapa[int(df_victor.loc[idx_diff[i], "Conflict"])])
  print()
# Out:
# Tipo:  Reply
# Tweet 1:  Bolsonaro quer aplicar Cloroquina a qualquer custo. Porém, o paciente precisará assinar um termo de ciência que NÃO existem dados sobre a eficiência para Covid-19 e que está ciente que pode sofrer uma parada cardíaca. Você vira cobaia do Presidente e o isenta de responsabilidade.
# Tweet 2:  tá na hora de deixar essa cloroquina quieta, e deixar o médico e o paciente resolverem essa questão;
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  A discussão sobre Cloroquina é falsa. Ela nunca foi proibida, nem será obrigatória. Os médicos mais atualizados, só prescrevem seguindo preceitos cientificos. Já os charlatões, usam de forma massiva pq nunca precisaram da ciência. A pressão do Bolsonaro não muda essa realidade.
# Tweet 2:  Imprensa imunda e os esquerdopatas lutando contra o uso da Cloroquina, estes imbecis já leram a bula da dipirona, que vc compra em qualquer padaria da esquina?
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  “Redução dos glóbulos brancos, disfunção do fígado, disfunção cardíaca e arritmias”
# Tweet 2:  Meu avô começou tomar cloroquina com 80 anos p reumatismo, morreu com 98 quando dormia.  No meu avô ñ teve todos esses efeitos colaterais não
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  Os médicos concordam que a proposta de tratamento deve ser conversada entre o médico e o paciente, da maneira “mais democrática e saudável possível”
# Tweet 2:  Se a cloroquina é a tal pq o paciente tem q assinar um termo de responsabilidade. Manda o general com cara de bebê sauro assinar.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  - Ainda não existe comprovação científica, mas sendo monitorada e usada no Brasil e no mundo. Contudo, estamos em Guerra: “Pior do que ser derrotado é a vergonha de não ter lutado.”  - Deus abençoe o nosso Brasil.
# Tweet 2:  Agora pode falar a verdade? Kkkk
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Aah tá bom, então a cloroquina só funciona com brasileiro e o mundo que lute! Nem rindo eu não tô mais... #chupauniverso
# Tweet 2:  #DEBATE360 VOCE NÃO TOMARIA A CLOROQUINA SE ESTIVESSE COM COVID SR ARHUR?
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito

# %%
#CLASSIFICAÇÕES POR CLASSES CAIO
print("CLASSIFICAÇÕES POR CLASSES CAIO:")
print("Cloroquina:")
print("Conflito:", df_caio[df_caio['Conflict'] == 1].shape[0])
print("Não conflito:", df_caio[df_caio['Conflict'] == 0].shape[0])
print("Indeterminado:", df_caio[df_caio['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES CAIO:
# Cloroquina:
# Conflito: 141
# Não conflito: 146
# Indeterminado: 13

# %%
#CLASSIFICAÇÕES POR CLASSES VICTOR
print("CLASSIFICAÇÕES POR CLASSES VICTOR:")
print("Cloroquina:")
print("Conflito:", df_victor[df_victor['Conflict'] == 1].shape[0])
print("Não conflito:", df_victor[df_victor['Conflict'] == 0].shape[0])
print("Indeterminado:", df_victor[df_victor['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES VICTOR:
# Cloroquina:
# Conflito: 158
# Não conflito: 136
# Indeterminado: 6

# %%
#Distribuição de conflitos por classes CAIO

#Separando as classes
reply_caio = df_caio[df_caio['Class'] == 1]
quote_caio = df_caio[df_caio['Class'] == 2]
original_caio = df_caio[df_caio['Class'] == 0]
print("Distribuição de conflitos por classes CAIO:")
print("Replys anotados:", reply_caio.shape[0])
print("Conflitos:", reply_caio[reply_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_caio[reply_caio['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_caio.shape[0])
print("Conflitos:", quote_caio[quote_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_caio[quote_caio['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_caio.shape[0])
print("Conflitos:", original_caio[original_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", original_caio[original_caio['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes CAIO:
# Replys anotados: 144
# Conflitos: 89
# Não conflitos: 54
#
# Quote anotados: 104
# Conflitos: 47
# Não conflitos: 49
#
# Originals anotados: 52
# Conflitos: 5
# Não conflitos: 43

# %%
#Distribuição de conflitos por classes VICTOR

#Separando as classes
reply_victor = df_victor[df_victor['Class'] == 1]
quote_victor = df_victor[df_victor['Class'] == 2]
original_victor = df_victor[df_victor['Class'] == 0]
print("Distribuição de conflitos por classes VICTOR:")
print("Replys anotados:", reply_victor.shape[0])
print("Conflitos:", reply_victor[reply_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_victor[reply_victor['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_victor.shape[0])
print("Conflitos:", quote_victor[quote_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_victor[quote_victor['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_victor.shape[0])
print("Conflitos:", original_victor[original_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", original_victor[original_victor['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes VICTOR:
# Replys anotados: 144
# Conflitos: 94
# Não conflitos: 49
#
# Quote anotados: 104
# Conflitos: 52
# Não conflitos: 47
#
# Originals anotados: 52
# Conflitos: 12
# Não conflitos: 40

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_caio[reply_caio['Conflict'] == 1].shape[0],
    quote_caio[quote_caio['Conflict'] == 1].shape[0],
    original_caio[original_caio['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_caio[reply_caio['Conflict'] == 0].shape[0],
    quote_caio[quote_caio['Conflict'] == 0].shape[0],
    original_caio[original_caio['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_caio[reply_caio['Conflict'] == -1].shape[0],
    quote_caio[quote_caio['Conflict'] == -1].shape[0],
    original_caio[original_caio['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class CAIO")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_victor[reply_victor['Conflict'] == 1].shape[0],
    quote_victor[quote_victor['Conflict'] == 1].shape[0],
    original_victor[original_victor['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_victor[reply_victor['Conflict'] == 0].shape[0],
    quote_victor[quote_victor['Conflict'] == 0].shape[0],
    original_victor[original_victor['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_victor[reply_victor['Conflict'] == -1].shape[0],
    quote_victor[quote_victor['Conflict'] == -1].shape[0],
    original_victor[original_victor['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class VICTOR")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# Previsoes incorretas CAIO:
df_inc_caio = df_caio[(df_caio['P(Conflict)'] > 0.5) & (df_caio['Conflict'] != 1)]
df_inc_caio.shape
# Out:
# (102, 6)

# %%
# Previsoes incorretas VICTOR:
df_inc_victor = df_victor[(df_victor['P(Conflict)'] > 0.5) & (df_victor['Conflict'] != 1)]
df_inc_victor.shape
# Out:
# (90, 6)

# %%
#Erros por classe de tweet CAIO
print("Erros por classe de tweet:")
print("Replys:", df_inc_caio[df_inc_caio['Class'] == 1].shape[0])
print("Quotes:", df_inc_caio[df_inc_caio['Class'] == 2].shape[0])
print("Originals:", df_inc_caio[df_inc_caio['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 35
# Quotes: 43
# Originals: 24

# %%
#Erros por classe de tweet VICTOR
print("Erros por classe de tweet:")
print("Replys:", df_inc_victor[df_inc_victor['Class'] == 1].shape[0])
print("Quotes:", df_inc_victor[df_inc_victor['Class'] == 2].shape[0])
print("Originals:", df_inc_victor[df_inc_victor['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 32
# Quotes: 38
# Originals: 20

# %%
#Organizando classificações de conflitos de Caio e Victor em um unico DF
df = df_caio.drop('Conflict', axis = 1)
df['Conflict_Caio'] = df_caio['Conflict']
df['Conflict_Victor'] = df_victor['Conflict']

# %%
df
# Out:
#                                                tweet_1  \
# 0    Bolsonaro finalmente conseguiu forçar o Min. d...
# 1    - Ainda não existe comprovação científica, mas...
# 2    Bolsonaro finalmente conseguiu forçar o Min. d...
# 3    - Ainda não existe comprovação científica, mas...
# 4    - Ainda não existe comprovação científica, mas...
# ..                                                 ...
# 295  Bolsonaro finalmente conseguiu forçar o Min. d...
# 296  Aos que apoiam a cloroquina, a tubaína ou o co...
# 297  - Ainda não existe comprovação científica, mas...
# 298  Além dos efeitos colaterais graves da cloroqui...
# 299  Bolsonaro admite que não há comprovação cientí...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1    Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2    Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3    vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4    "Não existe comprovação científica" Porra pres...      2       0.030527
# ..                                                 ...    ...            ...
# 295  A que ponto nós chegamos? Ninguém vai parar es...      2       0.061278
# 296  Antes a religião se opunha a ciência , hoje é ...      2       0.061418
# 297  Faça um pronunciamento em rede nacional mostra...      1       0.061510
# 298  Você sabe que o estudo de Manaus com pesquisad...      1       0.061512
# 299  Queria saber tb se há comprovação científica q...      2       0.061530
#
#      P(Conflict)  Conflict_Caio  Conflict_Victor
# 0       0.976709              1                1
# 1       0.971572              1                1
# 2       0.970327              1                1
# 3       0.969569              1                1
# 4       0.969473              1                1
# ..           ...            ...              ...
# 295     0.938722              0                0
# 296     0.938582              0                0
# 297     0.938490              0                0
# 298     0.938488              1                1
# 299     0.938470              0                0
#
# [300 rows x 7 columns]

# %%
df.to_csv("cloroquina_induzido_classificado.csv", index=False, encoding="utf-8")
files.download("cloroquina_induzido_classificado.csv")

# %% [markdown]
# # **Criando Dataset das divergencias**

# %%
div = df_caio.iloc[idx_diff].drop('Conflict', axis=1)
div['Conflict_caio'] = df_caio['Conflict'].iloc[idx_diff].astype(int)
div['Conflict_victor'] = df_victor['Conflict'].iloc[idx_diff].astype(int)
div['Conflict'] = np.nan

# %%
div.shape
# Out:
# (37, 8)

# %%
div
# Out:
#                                                tweet_1  \
# 23   Bolsonaro quer aplicar Cloroquina a qualquer c...
# 24   A discussão sobre Cloroquina é falsa. Ela nunc...
# 26   “Redução dos glóbulos brancos, disfunção do fí...
# 29   Os médicos concordam que a proposta de tratame...
# 32   Vi no Jornal da Globo uma descrição dos efeito...
# 35   Tomo cloroquina há 16 anos. A dosagem é super-...
# 41   Calma, bando de 0tári0.  O tratamento está aca...
# 54   Acha mesmo q o brasileiro com pouco esclarecim...
# 62   "tem tbm as pessoas q foram medicadas e recupe...
# 72   - Ainda não existe comprovação científica, mas...
# 76   Brasil renovou o recorde de mortes por coronav...
# 81   "Nós não faremos a distribuição e nem aplicaçã...
# 87   Do  no  : “sabe qual minha opiniao sobre a clo...
# 88   Mesmo que quiséssemos, sabe quais são os probl...
# 92   juro pra vcs que eu me esforço, mas não consig...
# 104  Agora cada médico receita a cloroquina quando ...
# 107                          Cloroquina, cloroquina...
# 109  Pessoal diz que cloroquina não tem efeitos con...
# 119  Meu pai me mandou um video da Nise Yamaguchi n...
# 128  pq a Unimed prescreve o uso da Cloroquina + az...
# 130  Continuarão ocorrendo mortes. Cloroquina é um ...
# 159                                    Prefiro tubaína
# 170  Essa experiência de demonizar a cloroquina vai...
# 172  A cloroquina é ocasionalmente usada no tratame...
# 175  A discussão sobre Cloroquina é falsa. Ela nunc...
# 183  Em SP o protocolo inclui todas as pajelanças: ...
# 186  Por que será que há tão pouco tempo a cloroqui...
# 188  Brasileiro toma por conta própria, Rivotril, t...
# 194  Será que quando o gov.federal publicar o proto...
# 198  Se um médico prescrever cloroquina eu nunca ma...
# 199  O Ministério da Saúde divulgou nova orientação...
# 214  Queridinha, sei muito bem os riscos e sei que ...
# 221  “O que o Ministério da Saúde está recomendando...
# 256  Prisão. Não tem lastro da ciência que dá resul...
# 257  - Ainda não existe comprovação científica, mas...
# 258  - Ainda não existe comprovação científica, mas...
# 283  Aah tá bom, então a cloroquina só funciona com...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 23   tá na hora de deixar essa cloroquina quieta, e...      1       0.059927
# 24   Imprensa imunda e os esquerdopatas lutando con...      0       0.067427
# 26   Meu avô começou tomar cloroquina com 80 anos p...      1       0.075467
# 29   Se a cloroquina é a tal pq o paciente tem q as...      1       0.080986
# 32   Ja leu as bulas da DIPIRONA, AS, e de outros c...      2       0.082830
# 35   Creio que seja controlada a dosagem ...e não f...      1       0.098667
# 41   Otários? Se existe um tratamento preventivo qu...      2       0.120484
# 54   Tenho parente que tem esclerose Múltipla , tom...      1       0.165254
# 62   Mtas pessoas foram recuperadas com vários trat...      1       0.185597
# 72                          não sou homofóbico, mas...      2       0.240157
# 76   Viva a liberdade de escolha, quem quiser tomar...      1       0.281288
# 81   PSDB Manipulação de Informações,  vocês não en...      2       0.301812
# 87   Não é questão de opinião e sim questão de libe...      1       0.340238
# 88               Esse paciente hipotético é complicado      2       0.341274
# 92   Quem quiser usa e quem não quiser não usa, pra...      0       0.363251
# 104  Cloroquina ou estriquinina, ele escolhe o que ...      1       0.437782
# 107                         QUEM NÃO QUISER, NÃO TOMA.      2       0.461902
# 109  Alguem me tira a dúvida, o ministério da saúde...      0       0.470042
# 119  Devotos da Cloroquina e aqueles que estão conf...      2       0.535215
# 128  Digitem "termo de ciência e consentimento clor...      0       0.590257
# 130  Os anta tão desesperados, o patrão vai perder ...      1       0.594751
# 159     Meu Deus... essa gente merece cloroquina mesmo      1       0.773445
# 170  Isto aqui é seríssimo.  Bolsonaro tentou alter...      0       0.812220
# 172  Alguém de vocês já tiveram que fazer algum exa...      0       0.826347
# 175  quem foi que colocou o mini bolsominion com a ...      0       0.835178
# 183  O motivo da minha resposta, foi um quanto ao  ...      1       0.850822
# 186  Cloroquina... esse nome lembra JB... lembra a ...      0       0.854408
# 188  Segundo pesquisas do médico indiano Dr. Jalim ...      0       0.855828
# 194  Cloroquina não! Hidroxicloroquina! A Hidroxicl...      1       0.868740
# 198  Se eu for em estado grave e um médico me presc...      2       0.873889
# 199  CHO SATANÁS SUA MALDITAAA  O MUNDOOO INTEIRO E...      2       0.877126
# 214  Mais obscurantista que isso é impossível. - ab...      1       0.057889
# 221  CLOROQUINA NUNCA precisou de prescrição   COMU...      2       0.058172
# 256  Já que a Cloroquina é a prisão, a vacina o que é?      2       0.059410
# 257  Eu só não entendo porque não podemos usar a Hi...      2       0.059411
# 258                   Agora pode falar a verdade? Kkkk      2       0.059542
# 283  #DEBATE360 VOCE NÃO TOMARIA A CLOROQUINA SE ES...      0       0.060665
#
#      P(Conflict)  Conflict_caio  Conflict_victor  Conflict
# 23      0.940073              0                1       NaN
# 24      0.932573              0                1       NaN
# 26      0.924533              1                0       NaN
# 29      0.919014              0                1       NaN
# 32      0.917170              0                1       NaN
# 35      0.901333              0                1       NaN
# 41      0.879516              0                1       NaN
# 54      0.834746              0                1       NaN
# 62      0.814403              0                1       NaN
# 72      0.759843              0               -1       NaN
# 76      0.718712              0                1       NaN
# 81      0.698188              1                0       NaN
# 87      0.659762              1                0       NaN
# 88      0.658726              0                1       NaN
# 92      0.636749              0                1       NaN
# 104     0.562218             -1                0       NaN
# 107     0.538098              0                1       NaN
# 109     0.529958              0                1       NaN
# 119     0.464785             -1                0       NaN
# 128     0.409743              1                0       NaN
# 130     0.405250              0                1       NaN
# 159     0.226555              0                1       NaN
# 170     0.187780             -1                1       NaN
# 172     0.173653              0                1       NaN
# 175     0.164822             -1                0       NaN
# 183     0.149178              1                0       NaN
# 186     0.145592             -1                1       NaN
# 188     0.144172              0                1       NaN
# 194     0.131260              0                1       NaN
# 198     0.126111              1                0       NaN
# 199     0.122874             -1                1       NaN
# 214     0.942111              1               -1       NaN
# 221     0.941828              1                0       NaN
# 256     0.940590             -1                1       NaN
# 257     0.940589              0                1       NaN
# 258     0.940458             -1                1       NaN
# 283     0.939335             -1                1       NaN

# %%
div_aborto_final = div.drop(columns=['Conflict_caio', 'Conflict_victor'])
div_aborto_final
# Out:
#                                                tweet_1  \
# 23   Bolsonaro quer aplicar Cloroquina a qualquer c...
# 24   A discussão sobre Cloroquina é falsa. Ela nunc...
# 26   “Redução dos glóbulos brancos, disfunção do fí...
# 29   Os médicos concordam que a proposta de tratame...
# 32   Vi no Jornal da Globo uma descrição dos efeito...
# 35   Tomo cloroquina há 16 anos. A dosagem é super-...
# 41   Calma, bando de 0tári0.  O tratamento está aca...
# 54   Acha mesmo q o brasileiro com pouco esclarecim...
# 62   "tem tbm as pessoas q foram medicadas e recupe...
# 72   - Ainda não existe comprovação científica, mas...
# 76   Brasil renovou o recorde de mortes por coronav...
# 81   "Nós não faremos a distribuição e nem aplicaçã...
# 87   Do  no  : “sabe qual minha opiniao sobre a clo...
# 88   Mesmo que quiséssemos, sabe quais são os probl...
# 92   juro pra vcs que eu me esforço, mas não consig...
# 104  Agora cada médico receita a cloroquina quando ...
# 107                          Cloroquina, cloroquina...
# 109  Pessoal diz que cloroquina não tem efeitos con...
# 119  Meu pai me mandou um video da Nise Yamaguchi n...
# 128  pq a Unimed prescreve o uso da Cloroquina + az...
# 130  Continuarão ocorrendo mortes. Cloroquina é um ...
# 159                                    Prefiro tubaína
# 170  Essa experiência de demonizar a cloroquina vai...
# 172  A cloroquina é ocasionalmente usada no tratame...
# 175  A discussão sobre Cloroquina é falsa. Ela nunc...
# 183  Em SP o protocolo inclui todas as pajelanças: ...
# 186  Por que será que há tão pouco tempo a cloroqui...
# 188  Brasileiro toma por conta própria, Rivotril, t...
# 194  Será que quando o gov.federal publicar o proto...
# 198  Se um médico prescrever cloroquina eu nunca ma...
# 199  O Ministério da Saúde divulgou nova orientação...
# 214  Queridinha, sei muito bem os riscos e sei que ...
# 221  “O que o Ministério da Saúde está recomendando...
# 256  Prisão. Não tem lastro da ciência que dá resul...
# 257  - Ainda não existe comprovação científica, mas...
# 258  - Ainda não existe comprovação científica, mas...
# 283  Aah tá bom, então a cloroquina só funciona com...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 23   tá na hora de deixar essa cloroquina quieta, e...      1       0.059927
# 24   Imprensa imunda e os esquerdopatas lutando con...      0       0.067427
# 26   Meu avô começou tomar cloroquina com 80 anos p...      1       0.075467
# 29   Se a cloroquina é a tal pq o paciente tem q as...      1       0.080986
# 32   Ja leu as bulas da DIPIRONA, AS, e de outros c...      2       0.082830
# 35   Creio que seja controlada a dosagem ...e não f...      1       0.098667
# 41   Otários? Se existe um tratamento preventivo qu...      2       0.120484
# 54   Tenho parente que tem esclerose Múltipla , tom...      1       0.165254
# 62   Mtas pessoas foram recuperadas com vários trat...      1       0.185597
# 72                          não sou homofóbico, mas...      2       0.240157
# 76   Viva a liberdade de escolha, quem quiser tomar...      1       0.281288
# 81   PSDB Manipulação de Informações,  vocês não en...      2       0.301812
# 87   Não é questão de opinião e sim questão de libe...      1       0.340238
# 88               Esse paciente hipotético é complicado      2       0.341274
# 92   Quem quiser usa e quem não quiser não usa, pra...      0       0.363251
# 104  Cloroquina ou estriquinina, ele escolhe o que ...      1       0.437782
# 107                         QUEM NÃO QUISER, NÃO TOMA.      2       0.461902
# 109  Alguem me tira a dúvida, o ministério da saúde...      0       0.470042
# 119  Devotos da Cloroquina e aqueles que estão conf...      2       0.535215
# 128  Digitem "termo de ciência e consentimento clor...      0       0.590257
# 130  Os anta tão desesperados, o patrão vai perder ...      1       0.594751
# 159     Meu Deus... essa gente merece cloroquina mesmo      1       0.773445
# 170  Isto aqui é seríssimo.  Bolsonaro tentou alter...      0       0.812220
# 172  Alguém de vocês já tiveram que fazer algum exa...      0       0.826347
# 175  quem foi que colocou o mini bolsominion com a ...      0       0.835178
# 183  O motivo da minha resposta, foi um quanto ao  ...      1       0.850822
# 186  Cloroquina... esse nome lembra JB... lembra a ...      0       0.854408
# 188  Segundo pesquisas do médico indiano Dr. Jalim ...      0       0.855828
# 194  Cloroquina não! Hidroxicloroquina! A Hidroxicl...      1       0.868740
# 198  Se eu for em estado grave e um médico me presc...      2       0.873889
# 199  CHO SATANÁS SUA MALDITAAA  O MUNDOOO INTEIRO E...      2       0.877126
# 214  Mais obscurantista que isso é impossível. - ab...      1       0.057889
# 221  CLOROQUINA NUNCA precisou de prescrição   COMU...      2       0.058172
# 256  Já que a Cloroquina é a prisão, a vacina o que é?      2       0.059410
# 257  Eu só não entendo porque não podemos usar a Hi...      2       0.059411
# 258                   Agora pode falar a verdade? Kkkk      2       0.059542
# 283  #DEBATE360 VOCE NÃO TOMARIA A CLOROQUINA SE ES...      0       0.060665
#
#      P(Conflict)  Conflict
# 23      0.940073       NaN
# 24      0.932573       NaN
# 26      0.924533       NaN
# 29      0.919014       NaN
# 32      0.917170       NaN
# 35      0.901333       NaN
# 41      0.879516       NaN
# 54      0.834746       NaN
# 62      0.814403       NaN
# 72      0.759843       NaN
# 76      0.718712       NaN
# 81      0.698188       NaN
# 87      0.659762       NaN
# 88      0.658726       NaN
# 92      0.636749       NaN
# 104     0.562218       NaN
# 107     0.538098       NaN
# 109     0.529958       NaN
# 119     0.464785       NaN
# 128     0.409743       NaN
# 130     0.405250       NaN
# 159     0.226555       NaN
# 170     0.187780       NaN
# 172     0.173653       NaN
# 175     0.164822       NaN
# 183     0.149178       NaN
# 186     0.145592       NaN
# 188     0.144172       NaN
# 194     0.131260       NaN
# 198     0.126111       NaN
# 199     0.122874       NaN
# 214     0.942111       NaN
# 221     0.941828       NaN
# 256     0.940590       NaN
# 257     0.940589       NaN
# 258     0.940458       NaN
# 283     0.939335       NaN

# %%
div_aborto_final.to_csv("divergencias_cloroquina_induzido.csv", index=False, encoding="utf-8")
files.download("divergencias_cloroquina_induzido.csv")

# %% [markdown]
# # **Criando Dataset das Convergencias**

# %%
conv_aborto = df_caio.drop(index=idx_diff, errors='ignore')
conv_aborto.shape
# Out:
# (263, 6)

# %%
conv_aborto
# Out:
#                                                tweet_1  \
# 0    Bolsonaro finalmente conseguiu forçar o Min. d...
# 1    - Ainda não existe comprovação científica, mas...
# 2    Bolsonaro finalmente conseguiu forçar o Min. d...
# 3    - Ainda não existe comprovação científica, mas...
# 4    - Ainda não existe comprovação científica, mas...
# ..                                                 ...
# 295  Bolsonaro finalmente conseguiu forçar o Min. d...
# 296  Aos que apoiam a cloroquina, a tubaína ou o co...
# 297  - Ainda não existe comprovação científica, mas...
# 298  Além dos efeitos colaterais graves da cloroqui...
# 299  Bolsonaro admite que não há comprovação cientí...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Espero que vc é tds a sua volta fiquem a salvo...      1       0.023291
# 1    Fez um inferno pra liberar esse caralho de med...      2       0.028428
# 2    Queria ver essa anta dessa Sâmia, fudida no ho...      1       0.029673
# 3    vc é uma criança mimada e pirracenta. desleixa...      1       0.030431
# 4    "Não existe comprovação científica" Porra pres...      2       0.030527
# ..                                                 ...    ...            ...
# 295  A que ponto nós chegamos? Ninguém vai parar es...      2       0.061278
# 296  Antes a religião se opunha a ciência , hoje é ...      2       0.061418
# 297  Faça um pronunciamento em rede nacional mostra...      1       0.061510
# 298  Você sabe que o estudo de Manaus com pesquisad...      1       0.061512
# 299  Queria saber tb se há comprovação científica q...      2       0.061530
#
#      P(Conflict)  Conflict
# 0       0.976709         1
# 1       0.971572         1
# 2       0.970327         1
# 3       0.969569         1
# 4       0.969473         1
# ..           ...       ...
# 295     0.938722         0
# 296     0.938582         0
# 297     0.938490         0
# 298     0.938488         1
# 299     0.938470         0
#
# [263 rows x 6 columns]

# %%
#juntando anotações do professor (QUANDO ELE ANOTAR)
#adicionando as classificações do professor
# file_class_prof = "1FSUrpSaiBAp5Gho-CsEw6kse3q4wCB8B"
# url = f"https://drive.google.com/uc?id={file_class_prof}"
# gdown.download(url, "class_prof.csv", quiet=False)
# df_class_prof = pd.read_csv ("class_prof.csv")

# %%
# df_class_prof

# %%
# df_desempate = div.iloc[:len(df_class_prof)-1,:]
# df_desempate

# %%
# df_desempate['Conflict_prof'] = df_class_prof['Conflict']
# df_desempate

# %%
# def resolver_conflito(row):
#     prof = row['Conflict_prof']
#     caio = row['Conflict_caio']
#     victor = row['Conflict_victor']

#     if prof == caio or prof == victor:
#         return prof
#     else:
#         return -1

# df_desempate['Conflict'] = df_desempate.apply(resolver_conflito, axis=1)

# %%
# df_desempate = df_desempate.drop(columns=['Conflict_caio', 'Conflict_victor', 'Conflict_prof'])
# df_desempate

# %%
# conv_aborto = pd.concat([conv_aborto, df_desempate], ignore_index=True, axis = 0)
# conv_aborto

# %%
conv_aborto.to_csv("convergencias_cloroquina_induzido.csv", index=False, encoding="utf-8")
files.download("convergencias_cloroquina_induzido.csv")
