# %% [markdown]
# # **Projeto de Graduação em Computação II [2026-Q1]**
#
# Universidade Federal do ABC
#
# Orientador Carlos da Silva dos Santos

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# Caio Cardoso Dos Santos - RA: 11202021632
#
# Victor Ravazio de Lima - RA: 11201920941

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %%
# modulo para importar dataset a partir de um link
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
#Bibliotecas
import pandas as pd
import numpy as np
from google.colab import files
import gdown
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
#Variaveis de controle
anotado = 400
# num_replys_anotados = 150
# num_quotes_anotados = 150
# num_originals_anotados = 150

# %%
# baixando dataset para o collab
import gdown

file_class_caio = "1ckE4_CHo6h4-2RuHOovi7oFxqUZ6_YIw"
file_class_victor = "1FamALJBfOegb407zpCKWuclX7v6nl_sG"
url_1 = f"https://drive.google.com/uc?id={file_class_caio}"
url_2 = f"https://drive.google.com/uc?id={file_class_victor}"

gdown.download(url_1, "mandetta_anotado_caio.csv", quiet=False)
gdown.download(url_2, "mandetta_anotado_victor.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ckE4_CHo6h4-2RuHOovi7oFxqUZ6_YIw
# To: /content/mandetta_anotado_caio.csv
# 100%|██████████| 11.1M/11.1M [00:00<00:00, 147MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FamALJBfOegb407zpCKWuclX7v6nl_sG
# To: /content/mandetta_anotado_victor.csv
# 100%|██████████| 11.1M/11.1M [00:00<00:00, 46.1MB/s]
# 'mandetta_anotado_victor.csv'

# %%
#carregando o dataset
df_caio = pd.read_csv ("mandetta_anotado_caio.csv")
df_victor = pd.read_csv ("mandetta_anotado_victor.csv")

# %%
#numero total de instancias no dataset
df_caio.shape
# Out:
# (36429, 6)

# %%
#numero total de instancias no dataset
df_victor.shape
# Out:
# (36429, 6)

# %%
df_caio.head(20)
# Out:
#                                               tweet_1  \
# 0   "E o Mandetta, a linha dele, como médico, era ...
# 1   Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2   Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3   É preciso reconhecer que se não fosse o SUS, n...
# 4   "E o Mandetta, a linha dele, como médico, era ...
# 5   Caminhamos para o abismo! Tirar  é urgente par...
# 6   “não vou mais me estressar com as merdas que e...
# 7   Na moral gente, tudo bem criticar o Bolsonaro ...
# 8   Ai vou morrer pq o Mandetta saiu!!!  Vai te fo...
# 9   A maioria esmagadora dos brasileiros é contrár...
# 10  O presidente nunca disse para não ficar em cas...
# 11  A maioria esmagadora dos brasileiros é contrár...
# 12  "E o Mandetta, a linha dele, como médico, era ...
# 13  Bolsonaro demitiu Mandetta por ciúme, inveja e...
# 14  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 15  Gente morrendo, o país em uma crise sem fim, n...
# 16  Vc que fala que é fã do Mandetta...  Fale três...
# 17  Em sua despedida, Mandetta defende a vida, o S...
# 18  "E o Mandetta, a linha dele, como médico, era ...
# 19  A maioria esmagadora dos brasileiros é contrár...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1   O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2   Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3   Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4    onde já se viu um médico preocupado com a vida ?      2       0.078197
# 5   Fernanda, o Bolsonaro está preservando vida, e...      2       0.085222
# 6   Não tem como não se estressar com oq ele faz q...      2       0.086673
# 7   o foco princípal do cara era o desmonte do SUS...      1       0.086982
# 8   Não seja inocente meu caro. Você sabe muito be...      1       0.095434
# 9   Senador, não se queime por uma MERDA como MAND...      1       0.105065
# 10  Votei Bolsonaro e acho q o Mandetta tá certo (...      2       0.107286
# 11  Pesquisa q vc acredita, o povo brasileiro não,...      1       0.112668
# 12  Então o coiso demitiu o Mandetta, pq ele se pr...      1       0.114328
# 13  Não  sabia q vc morria de amores por Mandetta....      1       0.114579
# 14  Obrigada Mandetta, vc tá realizado agora, eu n...      2       0.118062
# 15  Nem é ser chato, é ser racional. Político agin...      1       0.121140
# 16          Quais copas? Foi campeão da libertadores?      2       0.153840
# 17  Se um BOSTA como você está elogiando o Mandett...      1       0.173136
# 18  Ele era ministro da Saúde...  Ele deveria ser ...      2       0.186023
# 19  Vai com Deus Mandetta, desserviço com os brasi...      1       0.196411
#
#     P(Conflict)  Conflict
# 0      0.955778       0.0
# 1      0.950647       1.0
# 2      0.949967       1.0
# 3      0.929638       0.0
# 4      0.921803       0.0
# 5      0.914778       1.0
# 6      0.913327       0.0
# 7      0.913018       0.0
# 8      0.904567       1.0
# 9      0.894935       1.0
# 10     0.892714       0.0
# 11     0.887331       1.0
# 12     0.885672       0.0
# 13     0.885421       1.0
# 14     0.881938       1.0
# 15     0.878860       0.0
# 16     0.846160       0.0
# 17     0.826864       1.0
# 18     0.813977       0.0
# 19     0.803589       0.0

# %%
df_victor.head(20)
# Out:
#                                               tweet_1  \
# 0   "E o Mandetta, a linha dele, como médico, era ...
# 1   Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2   Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3   É preciso reconhecer que se não fosse o SUS, n...
# 4   "E o Mandetta, a linha dele, como médico, era ...
# 5   Caminhamos para o abismo! Tirar  é urgente par...
# 6   “não vou mais me estressar com as merdas que e...
# 7   Na moral gente, tudo bem criticar o Bolsonaro ...
# 8   Ai vou morrer pq o Mandetta saiu!!!  Vai te fo...
# 9   A maioria esmagadora dos brasileiros é contrár...
# 10  O presidente nunca disse para não ficar em cas...
# 11  A maioria esmagadora dos brasileiros é contrár...
# 12  "E o Mandetta, a linha dele, como médico, era ...
# 13  Bolsonaro demitiu Mandetta por ciúme, inveja e...
# 14  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 15  Gente morrendo, o país em uma crise sem fim, n...
# 16  Vc que fala que é fã do Mandetta...  Fale três...
# 17  Em sua despedida, Mandetta defende a vida, o S...
# 18  "E o Mandetta, a linha dele, como médico, era ...
# 19  A maioria esmagadora dos brasileiros é contrár...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1   O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2   Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3   Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4    onde já se viu um médico preocupado com a vida ?      2       0.078197
# 5   Fernanda, o Bolsonaro está preservando vida, e...      2       0.085222
# 6   Não tem como não se estressar com oq ele faz q...      2       0.086673
# 7   o foco princípal do cara era o desmonte do SUS...      1       0.086982
# 8   Não seja inocente meu caro. Você sabe muito be...      1       0.095434
# 9   Senador, não se queime por uma MERDA como MAND...      1       0.105065
# 10  Votei Bolsonaro e acho q o Mandetta tá certo (...      2       0.107286
# 11  Pesquisa q vc acredita, o povo brasileiro não,...      1       0.112668
# 12  Então o coiso demitiu o Mandetta, pq ele se pr...      1       0.114328
# 13  Não  sabia q vc morria de amores por Mandetta....      1       0.114579
# 14  Obrigada Mandetta, vc tá realizado agora, eu n...      2       0.118062
# 15  Nem é ser chato, é ser racional. Político agin...      1       0.121140
# 16          Quais copas? Foi campeão da libertadores?      2       0.153840
# 17  Se um BOSTA como você está elogiando o Mandett...      1       0.173136
# 18  Ele era ministro da Saúde...  Ele deveria ser ...      2       0.186023
# 19  Vai com Deus Mandetta, desserviço com os brasi...      1       0.196411
#
#     P(Conflict)  Conflict
# 0      0.955778       0.0
# 1      0.950647       1.0
# 2      0.949967       1.0
# 3      0.929638       0.0
# 4      0.921803       0.0
# 5      0.914778       1.0
# 6      0.913327       0.0
# 7      0.913018       0.0
# 8      0.904567       1.0
# 9      0.894935       1.0
# 10     0.892714       0.0
# 11     0.887331       0.0
# 12     0.885672       0.0
# 13     0.885421       1.0
# 14     0.881938      -1.0
# 15     0.878860       0.0
# 16     0.846160       0.0
# 17     0.826864       1.0
# 18     0.813977       0.0
# 19     0.803589       0.0

# %% [markdown]
# # **Analise Exploratória**

# %%
df_remaining = df_caio.iloc[anotado:,:]

# %%
# restrigindo por quantidade anotada
df_caio = df_caio.iloc[:anotado,:]
df_caio['Conflict'] = df_caio['Conflict'].astype(int) #convertendo valores para inteiros
df_victor = df_victor.iloc[:anotado,:]
df_victor['Conflict'] = df_victor['Conflict'].astype(int)

# %%
#separando por classe

# %%
df_caio
# Out:
#                                                tweet_1  \
# 0    "E o Mandetta, a linha dele, como médico, era ...
# 1    Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2    Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3    É preciso reconhecer que se não fosse o SUS, n...
# 4    "E o Mandetta, a linha dele, como médico, era ...
# ..                                                 ...
# 395  "E o Mandetta, a linha dele, como médico, era ...
# 396  para de endeusar o mandetta porra da pra ficar...
# 397  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 398  Em sua despedida, Mandetta defende a vida, o S...
# 399  "E o Mandetta, a linha dele, como médico, era ...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1    O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2    Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3    Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4     onde já se viu um médico preocupado com a vida ?      2       0.078197
# ..                                                 ...    ...            ...
# 395  Que coisa, um médico, defendendo vejam só, A VIDA      2       0.066134
# 396  ninguém tá endeusando o cara que queria privat...      2       0.066362
# 397  Nenhum capitalista gosta de quem trabalha. Ele...      2       0.066461
# 398  Caralho, Mandetta tava até ontem desmantelando...      2       0.066546
# 399        Um médico q prioriza a vida... Q coisa, né?      2       0.066713
#
#      P(Conflict)  Conflict
# 0       0.955778         0
# 1       0.950647         1
# 2       0.949967         1
# 3       0.929638         0
# 4       0.921803         0
# ..           ...       ...
# 395     0.933866         0
# 396     0.933638         1
# 397     0.933539         0
# 398     0.933454         1
# 399     0.933287         0
#
# [400 rows x 6 columns]

# %%
df_victor
# Out:
#                                                tweet_1  \
# 0    "E o Mandetta, a linha dele, como médico, era ...
# 1    Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2    Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3    É preciso reconhecer que se não fosse o SUS, n...
# 4    "E o Mandetta, a linha dele, como médico, era ...
# ..                                                 ...
# 395  "E o Mandetta, a linha dele, como médico, era ...
# 396  para de endeusar o mandetta porra da pra ficar...
# 397  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 398  Em sua despedida, Mandetta defende a vida, o S...
# 399  "E o Mandetta, a linha dele, como médico, era ...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1    O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2    Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3    Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4     onde já se viu um médico preocupado com a vida ?      2       0.078197
# ..                                                 ...    ...            ...
# 395  Que coisa, um médico, defendendo vejam só, A VIDA      2       0.066134
# 396  ninguém tá endeusando o cara que queria privat...      2       0.066362
# 397  Nenhum capitalista gosta de quem trabalha. Ele...      2       0.066461
# 398  Caralho, Mandetta tava até ontem desmantelando...      2       0.066546
# 399        Um médico q prioriza a vida... Q coisa, né?      2       0.066713
#
#      P(Conflict)  Conflict
# 0       0.955778         0
# 1       0.950647         1
# 2       0.949967         1
# 3       0.929638         0
# 4       0.921803         0
# ..           ...       ...
# 395     0.933866         0
# 396     0.933638         1
# 397     0.933539         0
# 398     0.933454         1
# 399     0.933287         0
#
# [400 rows x 6 columns]

# %%
confusion = np.zeros((3,3))

idx_diff = []  # lista com os índices i onde as classificações diferem

# %%
for i in range(df_caio.shape[0]):
  caio = int(df_caio.iloc[i]["Conflict"])
  victor = int(df_victor.iloc[i]["Conflict"])

  # mapeia -1 para 2 para a matriz 3x3
  row = 2 if caio == -1 else caio
  col = 2 if victor == -1 else victor

  confusion[row][col] += 1

  # se são diferentes (fora da diagonal principal)
  if row != col:
    idx_diff.append(i)

# %%
confusion
# Out:
# array([[225.,   8.,   3.],
#        [ 12., 138.,   2.],
#        [  6.,   4.,   2.]])

# %%
idx_diff
# Out:
# [11,
#  14,
#  21,
#  46,
#  54,
#  61,
#  84,
#  91,
#  96,
#  99,
#  120,
#  129,
#  130,
#  133,
#  148,
#  152,
#  156,
#  159,
#  160,
#  173,
#  178,
#  192,
#  224,
#  247,
#  264,
#  271,
#  279,
#  291,
#  303,
#  306,
#  359,
#  363,
#  380,
#  383,
#  385]

# %%
labels = ["0", "1", "-1"] # classes

plt.figure(figsize=(6,5))
sns.heatmap(confusion, annot=True, fmt=".0f", cmap="Blues", xticklabels=labels, yticklabels=labels) #desenha a matriz de confusão como uma "matriz de calor"

plt.xlabel("Predição Victor")
plt.ylabel("Predição Caio")
plt.title("Matriz de Confusão - Predição Pares")
plt.show()

# %%
mapa = {-1: "Indeterminado", 0: "Não Conflito", 1: "Conflito"}
mapa_tipo = {0: "Genérico", 1: "Reply", 2: "Quote"}

for i in range(len(idx_diff)):
  print("Tipo: ", mapa_tipo[int(df_caio.loc[idx_diff[i], "Class"])])
  print("Tweet 1: ", df_caio.loc[idx_diff[i], "tweet_1"])
  print("Tweet 2: ", df_caio.loc[idx_diff[i], "tweet_2"])
  print("Classificação Caio: ", mapa[int(df_caio.loc[idx_diff[i], "Conflict"])])
  print("Classificação Victor: ", mapa[int(df_victor.loc[idx_diff[i], "Conflict"])])
  print()
# Out:
# Tipo:  Reply
# Tweet 1:  A maioria esmagadora dos brasileiros é contrária à demissão de Mandetta: 76,2% dos entrevistados discordam do afastamento do ministro da Saúde, segundo pesquisa realizada pelo Atlas Político. Vc concorda com o resultado da pesquisa?   via
# Tweet 2:  Pesquisa q vc acredita, o povo brasileiro não, já vai tarde mandetta pau mandado
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  Acabo de ouvir do presidente Jair Bolsonaro o aviso da minha demissão do Ministério da Saúde.  Quero agradecer a oportunidade que me foi dada, de ser gerente do nosso SUS, de pôr de pé o projeto de melhoria da saúde dos brasileiros e
# Tweet 2:  Obrigada Mandetta, vc tá realizado agora, eu nemsabiq da sua existência antes de vc ser ministro, vá com Deus
# Classificação Caio:  Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Reply
# Tweet 1:  A maioria esmagadora dos brasileiros é contrária à demissão de Mandetta: 76,2% dos entrevistados discordam do afastamento do ministro da Saúde, segundo pesquisa realizada pelo Atlas Político. Vc concorda com o resultado da pesquisa?   via
# Tweet 2:  Óbvio que não Se 76% aprovam essa política de ideia isolamento do Mandetta, por que o "monitoramento" mostra 42% dentro de casa? Pesquisa mentirosa
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  Em sua despedida, Mandetta defende a vida, o SUS e a ciência. Três palavras incompatíveis com o atual governo.
# Tweet 2:  é a isso que vocês querem se comparar, ô caralho???? a questão é que o pete tem razões pra usar ministro privatista como exemplo positivo, a esquerda não
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  A maioria esmagadora dos brasileiros é contrária à demissão de Mandetta: 76,2% dos entrevistados discordam do afastamento do ministro da Saúde, segundo pesquisa realizada pelo Atlas Político. Vc concorda com o resultado da pesquisa?   via
# Tweet 2:  Não levo em consideração qualquer pesquisa que seja feita pelo grupo Abril. Já passou da hora do Mandetta cair fora!
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
#
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  Acabo de ouvir do presidente Jair Bolsonaro o aviso da minha demissão do Ministério da Saúde.  Quero agradecer a oportunidade que me foi dada, de ser gerente do nosso SUS, de pôr de pé o projeto de melhoria da saúde dos brasileiros e
# Tweet 2:  Porra de tweet é esse. É pra tacar fogo no parquinho, Mandetta, e não pra sair de fininho vestindo o manto do herói injustiçado. E que "nossos SUS" o quê, cê queria privatizar o SUS. FEZ BOM TRABALHO PRA SAIR DE CABEÇA BAIXA AGORA? NÃO, PORRA. TACA MERDA NO VENTILADOR.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  Ué, tá reclamando? Não foi vc mesmo que o indicou como um nome muito melhor que o Mandetta quando este foi anunciado em 2018? Kkkkkkkkkkk
# Tweet 2:  vc não engana mais ninguém
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Reply
# Tweet 1:  “Eu escolhi minha equipe por currículo..... ” “Nós temos a defesa da vida, a defesa do SUS e a defesa da ciência” Luiz Henrique Mandetta , Ministro da Saúde do Brasil.
# Tweet 2:  A defesa do SUS que ele foi a favor da privatização! O Brasil vai superar  sem Mandetta não tenho dúvidas.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  "E o Mandetta, a linha dele, como médico, era voltada quase exclusivamente para a vida" - Jair Bolsonaro, presidente do Brasil
# Tweet 2:  esse ministro é totalmente contra a vida considerando que ele já está morto
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  “Eu escolhi minha equipe por currículo..... ” “Nós temos a defesa da vida, a defesa do SUS e a defesa da ciência” Luiz Henrique Mandetta , Ministro da Saúde do Brasil.
# Tweet 2:  Bolsonaro tbm escolheu ministros TÉCNICOS e em sua maioria competentes e sem rabo preso!!! O q ñ o livrou de cometer o erro de escolher o sem vergonha do Mandetta.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  “onde eles se opõe” - presidente de planos de saúde - contra os mais médicos - favor do teto de gastos do SUS  a forma de se posicionar né.   e bom, em nenhum momento falei que o FREIXO estava idolatrando o mandetta mas sim muitas pessoas. a questão é que estamos numa situação+
# Tweet 2:  então, quando você chama a atenção pra forma de posicionar, você tem que levar em consideração que o Freixo está falando exclusivamente do recorte Mandetta - crise coronavirus. Não é como se em todo momento ele precisasse bater no Mandetta antes de falar dele.
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  Acabo de ouvir do presidente Jair Bolsonaro o aviso da minha demissão do Ministério da Saúde.  Quero agradecer a oportunidade que me foi dada, de ser gerente do nosso SUS, de pôr de pé o projeto de melhoria da saúde dos brasileiros e
# Tweet 2:  Vc e q diz Mandetta e pq foi demitido !!!
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito

# %%
#CLASSIFICAÇÕES POR CLASSES CAIO
print("CLASSIFICAÇÕES POR CLASSES CAIO:")
print("mandetta:")
print("Conflito:", df_caio[df_caio['Conflict'] == 1].shape[0])
print("Não conflito:", df_caio[df_caio['Conflict'] == 0].shape[0])
print("Indeterminado:", df_caio[df_caio['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES CAIO:
# mandetta:
# Conflito: 152
# Não conflito: 236
# Indeterminado: 12

# %%
#CLASSIFICAÇÕES POR CLASSES VICTOR
print("CLASSIFICAÇÕES POR CLASSES VICTOR:")
print("mandetta:")
print("Conflito:", df_victor[df_victor['Conflict'] == 1].shape[0])
print("Não conflito:", df_victor[df_victor['Conflict'] == 0].shape[0])
print("Indeterminado:", df_victor[df_victor['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES VICTOR:
# mandetta:
# Conflito: 150
# Não conflito: 243
# Indeterminado: 7

# %%
#Distribuição de conflitos por classes CAIO

#Separando as classes
reply_caio = df_caio[df_caio['Class'] == 1]
quote_caio = df_caio[df_caio['Class'] == 2]
original_caio = df_caio[df_caio['Class'] == 0]
print("Distribuição de conflitos por classes CAIO:")
print("Replys anotados:", reply_caio.shape[0])
print("Conflitos:", reply_caio[reply_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_caio[reply_caio['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_caio.shape[0])
print("Conflitos:", quote_caio[quote_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_caio[quote_caio['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_caio.shape[0])
print("Conflitos:", original_caio[original_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", original_caio[original_caio['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes CAIO:
# Replys anotados: 129
# Conflitos: 76
# Não conflitos: 50
#
# Quote anotados: 226
# Conflitos: 70
# Não conflitos: 147
#
# Originals anotados: 45
# Conflitos: 6
# Não conflitos: 39

# %%
#Distribuição de conflitos por classes VICTOR

#Separando as classes
reply_victor = df_victor[df_victor['Class'] == 1]
quote_victor = df_victor[df_victor['Class'] == 2]
original_victor = df_victor[df_victor['Class'] == 0]
print("Distribuição de conflitos por classes VICTOR:")
print("Replys anotados:", reply_victor.shape[0])
print("Conflitos:", reply_victor[reply_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_victor[reply_victor['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_victor.shape[0])
print("Conflitos:", quote_victor[quote_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_victor[quote_victor['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_victor.shape[0])
print("Conflitos:", original_victor[original_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", original_victor[original_victor['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes VICTOR:
# Replys anotados: 129
# Conflitos: 71
# Não conflitos: 56
#
# Quote anotados: 226
# Conflitos: 71
# Não conflitos: 150
#
# Originals anotados: 45
# Conflitos: 8
# Não conflitos: 37

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_caio[reply_caio['Conflict'] == 1].shape[0],
    quote_caio[quote_caio['Conflict'] == 1].shape[0],
    original_caio[original_caio['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_caio[reply_caio['Conflict'] == 0].shape[0],
    quote_caio[quote_caio['Conflict'] == 0].shape[0],
    original_caio[original_caio['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_caio[reply_caio['Conflict'] == -1].shape[0],
    quote_caio[quote_caio['Conflict'] == -1].shape[0],
    original_caio[original_caio['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class CAIO")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_victor[reply_victor['Conflict'] == 1].shape[0],
    quote_victor[quote_victor['Conflict'] == 1].shape[0],
    original_victor[original_victor['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_victor[reply_victor['Conflict'] == 0].shape[0],
    quote_victor[quote_victor['Conflict'] == 0].shape[0],
    original_victor[original_victor['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_victor[reply_victor['Conflict'] == -1].shape[0],
    quote_victor[quote_victor['Conflict'] == -1].shape[0],
    original_victor[original_victor['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class VICTOR")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# Previsoes incorretas CAIO:
df_inc_caio = df_caio[(df_caio['P(Conflict)'] > 0.5) & (df_caio['Conflict'] != 1)]
df_inc_caio.shape
# Out:
# (140, 6)

# %%
# Previsoes incorretas VICTOR:
df_inc_victor = df_victor[(df_victor['P(Conflict)'] > 0.5) & (df_victor['Conflict'] != 1)]
df_inc_victor.shape
# Out:
# (147, 6)

# %%
#Erros por classe de tweet CAIO
print("Erros por classe de tweet:")
print("Replys:", df_inc_caio[df_inc_caio['Class'] == 1].shape[0])
print("Quotes:", df_inc_caio[df_inc_caio['Class'] == 2].shape[0])
print("Originals:", df_inc_caio[df_inc_caio['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 15
# Quotes: 119
# Originals: 6

# %%
#Erros por classe de tweet VICTOR
print("Erros por classe de tweet:")
print("Replys:", df_inc_victor[df_inc_victor['Class'] == 1].shape[0])
print("Quotes:", df_inc_victor[df_inc_victor['Class'] == 2].shape[0])
print("Originals:", df_inc_victor[df_inc_victor['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 21
# Quotes: 120
# Originals: 6

# %%
#Organizando classificações de conflitos de Caio e Victor em um unico DF
df = df_caio.drop('Conflict', axis = 1)
df['Conflict_Caio'] = df_caio['Conflict']
df['Conflict_Victor'] = df_victor['Conflict']

# %%
df
# Out:
#                                                tweet_1  \
# 0    "E o Mandetta, a linha dele, como médico, era ...
# 1    Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2    Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3    É preciso reconhecer que se não fosse o SUS, n...
# 4    "E o Mandetta, a linha dele, como médico, era ...
# ..                                                 ...
# 395  "E o Mandetta, a linha dele, como médico, era ...
# 396  para de endeusar o mandetta porra da pra ficar...
# 397  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 398  Em sua despedida, Mandetta defende a vida, o S...
# 399  "E o Mandetta, a linha dele, como médico, era ...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1    O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2    Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3    Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4     onde já se viu um médico preocupado com a vida ?      2       0.078197
# ..                                                 ...    ...            ...
# 395  Que coisa, um médico, defendendo vejam só, A VIDA      2       0.066134
# 396  ninguém tá endeusando o cara que queria privat...      2       0.066362
# 397  Nenhum capitalista gosta de quem trabalha. Ele...      2       0.066461
# 398  Caralho, Mandetta tava até ontem desmantelando...      2       0.066546
# 399        Um médico q prioriza a vida... Q coisa, né?      2       0.066713
#
#      P(Conflict)  Conflict_Caio  Conflict_Victor
# 0       0.955778              0                0
# 1       0.950647              1                1
# 2       0.949967              1                1
# 3       0.929638              0                0
# 4       0.921803              0                0
# ..           ...            ...              ...
# 395     0.933866              0                0
# 396     0.933638              1                1
# 397     0.933539              0                0
# 398     0.933454              1                1
# 399     0.933287              0                0
#
# [400 rows x 7 columns]

# %%
df.to_csv("mandetta_induzido_classificado.csv", index=False, encoding="utf-8")
files.download("mandetta_induzido_classificado.csv")

# %% [markdown]
# # **Criando Dataset das divergencias**

# %%
div = df_caio.iloc[idx_diff].drop('Conflict', axis=1)
div['Conflict_caio'] = df_caio['Conflict'].iloc[idx_diff].astype(int)
div['Conflict_victor'] = df_victor['Conflict'].iloc[idx_diff].astype(int)
div['Conflict'] = np.nan

# %%
div.shape
# Out:
# (35, 8)

# %%
div
# Out:
#                                                tweet_1  \
# 11   A maioria esmagadora dos brasileiros é contrár...
# 14   Acabo de ouvir do presidente Jair Bolsonaro o ...
# 21   A maioria esmagadora dos brasileiros é contrár...
# 46   Em sua despedida, Mandetta defende a vida, o S...
# 54   A maioria esmagadora dos brasileiros é contrár...
# 61   “Jair conseguiu a proeza de transformar um pol...
# 84   Em sua despedida, Mandetta defende a vida, o S...
# 91   Em sua despedida, Mandetta defende a vida, o S...
# 96   nao se esqueçam mandetta era um lobbysta de pl...
# 99   Desejo boa sorte ao agora ex-ministro Mandetta...
# 120  Caralho to indignado que o Mandetta saiu antes...
# 279  O Mandetta votou a favor do Teto e Gastos q co...      2       0.053302
# 291  Ele escolheu deixar pessoas morrerem por não p...      1       0.054795
# 303  Porra de tweet é esse. É pra tacar fogo no par...      2       0.055825
# 306                         vc não engana mais ninguém      2       0.056282
# 359  A defesa do SUS que ele foi a favor da privati...      1       0.062285
# 363  esse ministro é totalmente contra a vida consi...      2       0.062588
# 380  Bolsonaro tbm escolheu ministros TÉCNICOS e em...      1       0.064480
# 383  então, quando você chama a atenção pra forma d...      1       0.064634
# 385          Vc e q diz Mandetta e pq foi demitido !!!      2       0.065223
#
#      P(Conflict)  Conflict_caio  Conflict_victor  Conflict
# 11      0.887331              1                0       NaN
# 14      0.881938              1               -1       NaN
# 21      0.766212              1                0       NaN
# 46      0.475004             -1                1       NaN
# 54      0.428085              1                0       NaN
# 61      0.380763             -1                0       NaN
# 84      0.214396             -1                1       NaN
# 91      0.185667              0                1       NaN
# 96      0.159682              1                0       NaN
# 99      0.141258              0                1       NaN
# 120     0.095382              0               -1       NaN
# 129     0.085437              0                1       NaN
# 130     0.084928              1                0       NaN
# 133     0.081151             -1                0       NaN
# 148     0.066828              0                1       NaN
# 152     0.064690              0               -1       NaN
# 156     0.058438              0                1       NaN
# 159     0.057321              0                1       NaN
# 160     0.057226              1               -1       NaN
# 173     0.052122             -1                0       NaN
# 178     0.049934             -1                0       NaN
# 192     0.043520              0                1       NaN
# 224     0.958717              1                0       NaN
# 247     0.953469             -1                1       NaN
# 264     0.950384              1                0       NaN
# 271     0.948007              1                0       NaN
# 279     0.946698              1                0       NaN
# 291     0.945205              1                0       NaN
# 303     0.944175              0                1       NaN
# 306     0.943718              0               -1       NaN
# 359     0.937715              1                0       NaN
# 363     0.937412             -1                0       NaN
# 380     0.935520              1                0       NaN
# 383     0.935366             -1                1       NaN
# 385     0.934777             -1                0       NaN

# %%
div_aborto_final = div.drop(columns=['Conflict_caio', 'Conflict_victor'])
div_aborto_final
# Out:
#                                                tweet_1  \
# 11   A maioria esmagadora dos brasileiros é contrár...
# 14   Acabo de ouvir do presidente Jair Bolsonaro o ...
# 21   A maioria esmagadora dos brasileiros é contrár...
# 46   Em sua despedida, Mandetta defende a vida, o S...
# 54   A maioria esmagadora dos brasileiros é contrár...
# 61   “Jair conseguiu a proeza de transformar um pol...
# 84   Em sua despedida, Mandetta defende a vida, o S...
# 91   Em sua despedida, Mandetta defende a vida, o S...
# 96   nao se esqueçam mandetta era um lobbysta de pl...
# 99   Desejo boa sorte ao agora ex-ministro Mandetta...
# 120  Caralho to indignado que o Mandetta saiu antes...
# 129  Auge e falarem mal do Mandetta a vão se fode g...
# 130  A maioria esmagadora dos brasileiros é contrár...
# 133  ⁦⁦⁩ escreve:  Entendam A Briga Entre Bolsonaro...
# 148  é uma sinuca de bico mesmo. saber que a demiss...
# 152  Mandetta deixa como legado uma estrutura para ...
# 156  É isso aí galera..O MANDETTA foi demitido..Ago...
# 159                      E para hoje, paz de espírito!
# 160  João Doria, Witzel, Mandetta, Maia: todos são ...
# 173  Demissão de Mandetta é rejeitada por 76% dos b...
# 385          Vc e q diz Mandetta e pq foi demitido !!!      2       0.065223
#
#      P(Conflict)  Conflict
# 11      0.887331       NaN
# 14      0.881938       NaN
# 21      0.766212       NaN
# 46      0.475004       NaN
# 54      0.428085       NaN
# 61      0.380763       NaN
# 84      0.214396       NaN
# 91      0.185667       NaN
# 96      0.159682       NaN
# 99      0.141258       NaN
# 120     0.095382       NaN
# 129     0.085437       NaN
# 130     0.084928       NaN
# 133     0.081151       NaN
# 148     0.066828       NaN
# 152     0.064690       NaN
# 156     0.058438       NaN
# 159     0.057321       NaN
# 160     0.057226       NaN
# 173     0.052122       NaN
# 178     0.049934       NaN
# 192     0.043520       NaN
# 224     0.958717       NaN
# 247     0.953469       NaN
# 264     0.950384       NaN
# 271     0.948007       NaN
# 279     0.946698       NaN
# 291     0.945205       NaN
# 303     0.944175       NaN
# 306     0.943718       NaN
# 359     0.937715       NaN
# 363     0.937412       NaN
# 380     0.935520       NaN
# 383     0.935366       NaN
# 385     0.934777       NaN

# %%
div_aborto_final.to_csv("divergencias_mandetta_induzido.csv", index=False, encoding="utf-8")
files.download("divergencias_mandetta_induzido.csv")

# %% [markdown]
# # **Criando Dataset das Convergencias**

# %%
conv_aborto = df_caio.drop(index=idx_diff, errors='ignore')
conv_aborto.shape
# Out:
# (365, 6)

# %%
conv_aborto
# Out:
#                                                tweet_1  \
# 0    "E o Mandetta, a linha dele, como médico, era ...
# 1    Acabo de ouvir do presidente Jair Bolsonaro o ...
# 2    Boa sorte ao Nelson Teich, novo ministro da Sa...
# 3    É preciso reconhecer que se não fosse o SUS, n...
# 4    "E o Mandetta, a linha dele, como médico, era ...
# ..                                                 ...
# 395  "E o Mandetta, a linha dele, como médico, era ...
# 396  para de endeusar o mandetta porra da pra ficar...
# 397  Acabo de ouvir do presidente Jair Bolsonaro o ...
# 398  Em sua despedida, Mandetta defende a vida, o S...
# 399  "E o Mandetta, a linha dele, como médico, era ...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Tá certo, tem que demitir um ministro da SAÚDE...      2       0.044222
# 1    O privatizador e lobista dos planos de saúde f...      2       0.049353
# 2    Fala verdade seu safado, vc torce pro quanto p...      1       0.050033
# 3    Esse mesmo SUS que o Mandetta defendeu o fim e...      2       0.070362
# 4     onde já se viu um médico preocupado com a vida ?      2       0.078197
# ..                                                 ...    ...            ...
# 395  Que coisa, um médico, defendendo vejam só, A VIDA      2       0.066134
# 396  ninguém tá endeusando o cara que queria privat...      2       0.066362
# 397  Nenhum capitalista gosta de quem trabalha. Ele...      2       0.066461
# 398  Caralho, Mandetta tava até ontem desmantelando...      2       0.066546
# 399        Um médico q prioriza a vida... Q coisa, né?      2       0.066713
#
#      P(Conflict)  Conflict
# 0       0.955778         0
# 1       0.950647         1
# 2       0.949967         1
# 3       0.929638         0
# 4       0.921803         0
# ..           ...       ...
# 395     0.933866         0
# 396     0.933638         1
# 397     0.933539         0
# 398     0.933454         1
# 399     0.933287         0
#
# [365 rows x 6 columns]

# %%
#juntando anotações do professor (QUANDO ELE ANOTAR)
#adicionando as classificações do professor
# file_class_prof = "1FSUrpSaiBAp5Gho-CsEw6kse3q4wCB8B"
# url = f"https://drive.google.com/uc?id={file_class_prof}"
# gdown.download(url, "class_prof.csv", quiet=False)
# df_class_prof = pd.read_csv ("class_prof.csv")

# %%
# df_class_prof

# %%
# df_desempate = div.iloc[:len(df_class_prof)-1,:]
# df_desempate

# %%
# df_desempate['Conflict_prof'] = df_class_prof['Conflict']
# df_desempate

# %%
# def resolver_conflito(row):
#     prof = row['Conflict_prof']
#     caio = row['Conflict_caio']
#     victor = row['Conflict_victor']

#     if prof == caio or prof == victor:
#         return prof
#     else:
#         return -1

# df_desempate['Conflict'] = df_desempate.apply(resolver_conflito, axis=1)

# %%
# df_desempate = df_desempate.drop(columns=['Conflict_caio', 'Conflict_victor', 'Conflict_prof'])
# df_desempate

# %%
# conv_aborto = pd.concat([conv_aborto, df_desempate], ignore_index=True, axis = 0)
# conv_aborto

# %%
conv_aborto.to_csv("convergencias_mandetta_induzido.csv", index=False, encoding="utf-8")
files.download("convergencias_mandetta_induzido.csv")

# %% [markdown]
# # **Criando dataset dos não anotados**

# %%
df_remaining
# Out:
#                                                  tweet_1  \
# 400    Acabo de ouvir do presidente Jair Bolsonaro o ...
# 401    Mandetta não caiu pq seguia as recomendações d...
# 402    "E o Mandetta, a linha dele, como médico, era ...
# 403    A ciência foi demitida. Mas será substituída p...
# 404    Sou Mandetta, sou Isolamento Social, sou pela ...
# ...                                                  ...
# 36424  Bozonaro demitiu Mandetta.  Tufão expulsou Car...
# 36425  O presidente da Câmara tem em sua gaveta um pe...
# 36426  Mandetta está oficialmente demitido. Que Bolso...
# 36427  URGENTE: Bolsonaro demite Mandetta do Ministér...
# 36428  Mandetta fora do cargo de ministro, já prevejo...
#
#                                                  tweet_2  Class  \
# 400    E o Mandetta aclamando o SUS?  Quem não te con...      2
# 401    Pois é, ele é um grande lobista da saúde priva...      1
# 402    Opa mas acho que vc tipo jura isso aí mesmo qu...      2
# 403    Ñ existia ciência n Mandetta existia um políti...      2
# 404    Vendetta é um criminoso e assassino! Se és pel...      2
# ...                                                  ...    ...
# 36424  Davi Alcolumbre e de pelo menos dois ministros...      0
# 36425  Receba  #ImpeachmentBolsonaro #ForaBolsonaroUr...      2
# 36426  Amém! #MandettaDEMITIDO  #AbortoNao  #PLP149NA...      2
# 36427  Exonerado por fazer um bom trabalho #mandetta2...      2
# 36428  8 Erros do Mandetta e Demissão!   #ForaMandett...      0
#
#        P(NoConflict)  P(Conflict)  Conflict
# 400         0.066796     0.933204       NaN
# 401         0.067077     0.932923       NaN
# 402         0.067107     0.932893       NaN
# 403         0.067172     0.932828       NaN
# 404         0.067265     0.932735       NaN
# ...              ...          ...       ...
# 36424       0.995735     0.004266       NaN
# 36425       0.995739     0.004261       NaN
# 36426       0.995819     0.004181       NaN
# 36427       0.996007     0.003993       NaN
# 36428       0.996021     0.003979       NaN
#
# [36029 rows x 6 columns]

# %%
df_remaining.to_csv("nao_anotados_mandetta_induzido.csv", index=False, encoding="utf-8")
files.download("nao_anotados_mandetta_induzido.csv")
