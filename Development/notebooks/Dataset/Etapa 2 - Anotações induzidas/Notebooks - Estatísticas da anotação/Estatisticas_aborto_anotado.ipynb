# %% [markdown]
# # **Projeto de Graduação em Computação II [2026-Q1]**
#
# Universidade Federal do ABC
#
# Orientador Carlos da Silva dos Santos

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# Caio Cardoso Dos Santos - RA: 11202021632
#
# Victor Ravazio de Lima - RA: 11201920941

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %%
# modulo para importar dataset a partir de um link
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.7)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.6.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
#Bibliotecas
import pandas as pd
import numpy as np
from google.colab import files
import gdown
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
#Variaveis de controle
anotado = 400
# num_replys_anotados = 150
# num_quotes_anotados = 150
# num_originals_anotados = 150

# %%
# baixando dataset para o collab
import gdown

file_class_caio = "1C5adI1xq00fW3HVTWbafQJWj5NapGOkG"
file_class_victor = "1G-TC7qDMpJyrGdfqsZgr3yFEegLr0dcB"
url_1 = f"https://drive.google.com/uc?id={file_class_caio}"
url_2 = f"https://drive.google.com/uc?id={file_class_victor}"

gdown.download(url_1, "Aborto_anotado_caio.csv", quiet=False)
gdown.download(url_2, "Aborto_anotado_victor.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1C5adI1xq00fW3HVTWbafQJWj5NapGOkG
# To: /content/Aborto_anotado_caio.csv
# 100%|██████████| 4.38M/4.38M [00:00<00:00, 25.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1G-TC7qDMpJyrGdfqsZgr3yFEegLr0dcB
# To: /content/Aborto_anotado_victor.csv
# 100%|██████████| 4.38M/4.38M [00:00<00:00, 233MB/s]
# 'Aborto_anotado_victor.csv'

# %%
#carregando o dataset
df_caio = pd.read_csv ("Aborto_anotado_caio.csv")
df_victor = pd.read_csv ("Aborto_anotado_victor.csv")

# %%
#numero total de instancias no dataset
df_caio.shape
# Out:
# (14249, 6)

# %%
#numero total de instancias no dataset
df_victor.shape
# Out:
# (14249, 6)

# %%
df_caio.head(20)
# Out:
#                                               tweet_1  \
# 0   Estamos em 2020 século 21, as mulheres ainda n...
# 1                    #AbortoNao Jamais ! Sim a vida .
# 2   #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3   Alguém pode me explicar quem levantou a pauta ...
# 4   Aborto não é método contraceptivo!antes de esc...
# 5   Pelo simples fato de que matar uma vida humana...
# 6   Bagaço pqp, eu nao estou gravido pq sou homem,...
# 7                       #AbortoSim ELAS QUE DECIDEM !
# 8   O mais engraçado é que a maioria é homem que v...
# 9   "Ah, mas você vai matar uma vida" Oh seus band...
# 10  A vida que vai ser estraga é a da criança, que...
# 11  Mano eu sinceramente fico decepcionada que ano...
# 12  E tem homem comentando nas tags porque? Vcs te...
# 13  Já que todo mundo tá falando sobre isso...Eu s...
# 14  “Se somos escravos do ontem, somos donos de no...
# 15  Vamos ser coerentes, não faz sentido tirar a v...
# 16  Sou a favor do aborto em todos os casos. #Abor...
# 17        #AbortoNao Bando de vagabundas e feministos
# 18  Sem condições e acaba abandonando na rua, você...
# 19  Sim é o meu corpo, sim é a minha escolha. Inde...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1   Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2   vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 4   Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# 5   @ Vida é a partir do embrião.E embrião é vida....      1       0.040479
# 6   #abortonao. Se você defende que a mulher faça ...      1       0.041120
# 7   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 8   a mulher tem a escolha de querer abortar ou nã...      0       0.042705
# 9   não é melhor usar preservativo e outros método...      0       0.042775
# 10  Se tu matar todos os que não são amados ou que...      1       0.043636
# 11  Tá bom macho hetero, o aborto é escolha sua né...      0       0.043723
# 12  Útero eu não tenho mas eu tenho uma vida graça...      1       0.044162
# 13  você eh a favor da vida ou do nascimento???? p...      0       0.044518
# 14  o engraçado é que quando você entra no “aborto...      0       0.045212
# 15  #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 16  Enquanto você grita fica em casa,  em quarente...      1       0.046448
# 17  O estado tem q parar de se meter na vida priva...      0       0.046596
# 18  Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 19  Concordo e respeito que seja a tua escolha, ma...      2       0.048438
#
#     P(Conflict)  Conflict
# 0      0.970027       0.0
# 1      0.964738       1.0
# 2      0.964286       0.0
# 3      0.961901       0.0
# 4      0.961731       1.0
# 5      0.959521       1.0
# 6      0.958880       1.0
# 7      0.958238      -1.0
# 8      0.957295       0.0
# 9      0.957224       1.0
# 10     0.956364       1.0
# 11     0.956277       0.0
# 12     0.955838       1.0
# 13     0.955482       0.0
# 14     0.954788       1.0
# 15     0.954625       1.0
# 16     0.953552       1.0
# 17     0.953404       1.0
# 18     0.952196       1.0
# 19     0.951562       1.0

# %%
df_victor.head(20)
# Out:
#                                               tweet_1  \
# 0   Estamos em 2020 século 21, as mulheres ainda n...
# 1                    #AbortoNao Jamais ! Sim a vida .
# 2   #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3   Alguém pode me explicar quem levantou a pauta ...
# 4   Aborto não é método contraceptivo!antes de esc...
# 5   Pelo simples fato de que matar uma vida humana...
# 6   Bagaço pqp, eu nao estou gravido pq sou homem,...
# 7                       #AbortoSim ELAS QUE DECIDEM !
# 8   O mais engraçado é que a maioria é homem que v...
# 9   "Ah, mas você vai matar uma vida" Oh seus band...
# 10  A vida que vai ser estraga é a da criança, que...
# 11  Mano eu sinceramente fico decepcionada que ano...
# 12  E tem homem comentando nas tags porque? Vcs te...
# 13  Já que todo mundo tá falando sobre isso...Eu s...
# 14  “Se somos escravos do ontem, somos donos de no...
# 15  Vamos ser coerentes, não faz sentido tirar a v...
# 16  Sou a favor do aborto em todos os casos. #Abor...
# 17        #AbortoNao Bando de vagabundas e feministos
# 18  Sem condições e acaba abandonando na rua, você...
# 19  Sim é o meu corpo, sim é a minha escolha. Inde...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1   Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2   vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 4   Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# 5   @ Vida é a partir do embrião.E embrião é vida....      1       0.040479
# 6   #abortonao. Se você defende que a mulher faça ...      1       0.041120
# 7   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 8   a mulher tem a escolha de querer abortar ou nã...      0       0.042705
# 9   não é melhor usar preservativo e outros método...      0       0.042775
# 10  Se tu matar todos os que não são amados ou que...      1       0.043636
# 11  Tá bom macho hetero, o aborto é escolha sua né...      0       0.043723
# 12  Útero eu não tenho mas eu tenho uma vida graça...      1       0.044162
# 13  você eh a favor da vida ou do nascimento???? p...      0       0.044518
# 14  o engraçado é que quando você entra no “aborto...      0       0.045212
# 15  #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 16  Enquanto você grita fica em casa,  em quarente...      1       0.046448
# 17  O estado tem q parar de se meter na vida priva...      0       0.046596
# 18  Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 19  Concordo e respeito que seja a tua escolha, ma...      2       0.048438
#
#     P(Conflict)  Conflict
# 0      0.970027       0.0
# 1      0.964738       1.0
# 2      0.964286       0.0
# 3      0.961901       1.0
# 4      0.961731       1.0
# 5      0.959521       1.0
# 6      0.958880       1.0
# 7      0.958238       0.0
# 8      0.957295       0.0
# 9      0.957224       1.0
# 10     0.956364       1.0
# 11     0.956277       0.0
# 12     0.955838       1.0
# 13     0.955482       0.0
# 14     0.954788       0.0
# 15     0.954625       0.0
# 16     0.953552       1.0
# 17     0.953404       1.0
# 18     0.952196       0.0
# 19     0.951562       1.0

# %% [markdown]
# # **Analise Exploratória**

# %%
df_remaining = df_caio.iloc[anotado:,:]
# restrigindo por quantidade anotada
df_caio = df_caio.iloc[:anotado,:]
df_caio['Conflict'] = df_caio['Conflict'].astype(int) #convertendo valores para inteiros
df_victor = df_victor.iloc[:anotado,:]
df_victor['Conflict'] = df_victor['Conflict'].astype(int)

# %%
#separando por classe

# %%
df_caio
# Out:
#                                                tweet_1  \
# 0    Estamos em 2020 século 21, as mulheres ainda n...
# 1                     #AbortoNao Jamais ! Sim a vida .
# 2    #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3    Alguém pode me explicar quem levantou a pauta ...
# 4    Aborto não é método contraceptivo!antes de esc...
# ..                                                 ...
# 395  mano pq tem uma tag contra aborto nos trends e...
# 396  Coleguinha que apoia essa maldita tag do #Abor...
# 397  #AbortoNao  Gente uma criança não é um castigo...
# 398  ser isso for legalizado ninguém vai ser obriga...
# 399       Respeite a vida Desde a concepção #AbortoNao
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1    Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2    vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3    Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 4    Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# ..                                                 ...    ...            ...
# 395  tem q ser muito babaca pra ser contra o aborto...      0       0.042105
# 396  Já que  defende tanto o aborto ,acho que o err...      0       0.042106
# 397  a mulher quer abortar, vcs não deixam as gays ...      0       0.042113
# 398  ABORTO NÃO!!! Vc não tem direito sobre a VIDA!...      0       0.042124
# 399  toma no cu todo mundo, o útero é da mina se el...      0       0.042142
#
#      P(Conflict)  Conflict
# 0       0.970027         0
# 1       0.964738         1
# 2       0.964286         0
# 3       0.961901         0
# 4       0.961731         1
# ..           ...       ...
# 395     0.957895         0
# 396     0.957894         0
# 397     0.957887         0
# 398     0.957876         1
# 399     0.957858         1
#
# [400 rows x 6 columns]

# %%
df_victor
# Out:
#                                                tweet_1  \
# 0    Estamos em 2020 século 21, as mulheres ainda n...
# 1                     #AbortoNao Jamais ! Sim a vida .
# 2    #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3    Alguém pode me explicar quem levantou a pauta ...
# 4    Aborto não é método contraceptivo!antes de esc...
# ..                                                 ...
# 395  mano pq tem uma tag contra aborto nos trends e...
# 396  Coleguinha que apoia essa maldita tag do #Abor...
# 397  #AbortoNao  Gente uma criança não é um castigo...
# 398  ser isso for legalizado ninguém vai ser obriga...
# 399       Respeite a vida Desde a concepção #AbortoNao
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1    Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2    vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3    Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 4    Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# ..                                                 ...    ...            ...
# 395  tem q ser muito babaca pra ser contra o aborto...      0       0.042105
# 396  Já que  defende tanto o aborto ,acho que o err...      0       0.042106
# 397  a mulher quer abortar, vcs não deixam as gays ...      0       0.042113
# 398  ABORTO NÃO!!! Vc não tem direito sobre a VIDA!...      0       0.042124
# 399  toma no cu todo mundo, o útero é da mina se el...      0       0.042142
#
#      P(Conflict)  Conflict
# 0       0.970027         0
# 1       0.964738         1
# 2       0.964286         0
# 3       0.961901         1
# 4       0.961731         1
# ..           ...       ...
# 395     0.957895         0
# 396     0.957894         0
# 397     0.957887         0
# 398     0.957876         1
# 399     0.957858         1
#
# [400 rows x 6 columns]

# %%
confusion = np.zeros((3,3))

idx_diff = []  # lista com os índices i onde as classificações diferem

# %%
for i in range(df_caio.shape[0]):
  caio = int(df_caio.iloc[i]["Conflict"])
  victor = int(df_victor.iloc[i]["Conflict"])

  # mapeia -1 para 2 para a matriz 3x3
  row = 2 if caio == -1 else caio
  col = 2 if victor == -1 else victor

  confusion[row][col] += 1

  # se são diferentes (fora da diagonal principal)
  if row != col:
    idx_diff.append(i)

# %%
confusion
# Out:
# array([[156.,  23.,   8.],
#        [ 15., 180.,   2.],
#        [  7.,   5.,   4.]])

# %%
idx_diff
# Out:
# [3,
#  7,
#  14,
#  15,
#  18,
#  29,
#  31,
#  33,
#  49,
#  50,
#  56,
#  57,
#  58,
#  82,
#  85,
#  87,
#  88,
#  92,
#  106,
#  110,
#  113,
#  116,
#  119,
#  128,
#  136,
#  137,
#  139,
#  143,
#  166,
#  172,
#  177,
#  186,
#  191,
#  216,
#  226,
#  231,
#  252,
#  265,
#  285,
#  294,
#  296,
#  308,
#  309,
#  318,
#  321,
#  327,
#  337,
#  340,
#  341,
#  344,
#  346,
#  353,
#  356,
#  364,
#  366,
#  367,
#  371,
#  374,
#  377,
#  383]

# %%
labels = ["0", "1", "-1"] # classes

plt.figure(figsize=(6,5))
sns.heatmap(confusion, annot=True, fmt=".0f", cmap="Blues", xticklabels=labels, yticklabels=labels) #desenha a matriz de confusão como uma "matriz de calor"

plt.xlabel("Classificação Autor 2")
plt.ylabel("Classificação Autor 1")
plt.title("Matriz de Confusão - Classificação em Pares")
plt.show()

# %%
mapa = {-1: "Indeterminado", 0: "Não Conflito", 1: "Conflito"}
mapa_tipo = {0: "Genérico", 1: "Reply", 2: "Quote"}

for i in range(len(idx_diff)):
  print("Tipo: ", mapa_tipo[int(df_caio.loc[idx_diff[i], "Class"])])
  print("Tweet 1: ", df_caio.loc[idx_diff[i], "tweet_1"])
  print("Tweet 2: ", df_caio.loc[idx_diff[i], "tweet_2"])
  print("Classificação Caio: ", mapa[int(df_caio.loc[idx_diff[i], "Conflict"])])
  print("Classificação Victor: ", mapa[int(df_victor.loc[idx_diff[i], "Conflict"])])
  print()
# Out:
# Tipo:  Genérico
# Tweet 1:  Alguém pode me explicar quem levantou a pauta de aborto ontem? De onde surgiu e como? Eu não entendi nada, peguei o bonde andando. Só sei que #AbortoNao.
# Tweet 2:  Se vc vem opinar numa tag feminina sendo contra o aborto tudo q vc disser será automaticamente anulado e a gente vai zuar com sua cara #AbortoSim
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  #AbortoSim ELAS QUE DECIDEM !
# Tweet 2:  Ai que inferno, é vc que está com o feto no útero, se não o #AbortoNao é da sua conta. Pelo amor
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito
#
# Tipo:  Genérico
# Tweet 1:  “Se somos escravos do ontem, somos donos de nosso amanhã.”  #AbortoNao
# Tweet 2:  o engraçado é que quando você entra no “aborto não” só tem macho escroto, querendo colocar o dedinho aonde não foi chamado. nos poupe de tanta merda. #AbortoSim
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
#
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Agora papo reto. O aborto devia ser legalizado sim, mas pra um caso especifico que no caso, é o estupro.  PORQUE SE TU É UMA FILHA DA PUTA  UMA FILHA DA PUTA QUE ABRE A PORRA DA PERNA E DEPOIS FICA "uiUIUUUiuiuuiiuiuiuiuiuUIUIUiuuiuiuIUIUiuiuiUiuIuUi VO ABORTA" VTNC  #AbortoNao
# Tweet 2:  Você que é contra o aborto, o que sente quando vê uma criança pequena vendendo bala no sinal? O que você fez por ela?  #AbortoNao
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Estima-se que são realizados mais de 57 milhões de abortos todos os anos ao redor do mundo. Isso corresponde a mais de 5 holocaustos anualmente. Milhões de bebês assassinados a sangue frio ainda no ventre de suas mães. #AbortoNao
# Tweet 2:  Se vc é cristão, pq invés de subir a #AbortoNAO, vc n vai orar pra q a educação sexual chegue a todos, pra n ocorrer mais casos de gravidez acidental #AbortoSim
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  #AbortoSim porque proibir não impede que alguém aborte. E quem não adota criança não pode ser contra o aborto, fora que o aborto legalizado é melhor para a economia. hipócritas.
# Tweet 2:  Vocês não estão prontos para está conversa, e vão se foder, cada argumento mais bosta que  o outro.  Só tem homem babaca falando merda #abortosim #AbortoNao
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Alguns já esqueceram dessas frases maravilhosas.  "Vim para que tenham vida" "Te conheço antes mesmo de se formar no ventre" "Não matarás"  E ainda tem "cristão" que apoia aborto. #AbortoNao
# Tweet 2:  ai gente, desnecessário #abortosim e #abortonão, deixa a mulher grávida decidir gente, quem vai ter q cuidar vai ser ela, quem vai se preocupar vai ser ela. Se ela não quiser um filho pq não tem condições financeiras ou psicológicas, ngm de vocês vão querer ajudar a mãe.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Parem de usar como argumento a questão de quando começa a vida. NÃO EXISTE CONSENSO CIENTÍFICO SOBRE ISSO, portanto, não  é  um argumento válido, no final você vai estar só defendendo sua opinião. #AbortoNao
# Tweet 2:  a galera do #AbortoNao é muito engraçadaKFKDKDK amg se sua religião não permite, se vc acha errado, se vc acha que é assassinato então não aborta ue, mas outras mulheres que não querem ou que foram estupradas não merecem viver com essa lembrança de trauma ou ódio  #AbortoSim
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito

# %%
#CLASSIFICAÇÕES POR CLASSES CAIO
print("CLASSIFICAÇÕES POR CLASSES CAIO:")
print("Aborto:")
print("Conflito:", df_caio[df_caio['Conflict'] == 1].shape[0])
print("Não conflito:", df_caio[df_caio['Conflict'] == 0].shape[0])
print("Indeterminado:", df_caio[df_caio['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES CAIO:
# Aborto:
# Conflito: 197
# Não conflito: 187
# Indeterminado: 16

# %%
#CLASSIFICAÇÕES POR CLASSES VICTOR
print("CLASSIFICAÇÕES POR CLASSES VICTOR:")
print("Aborto:")
print("Conflito:", df_victor[df_victor['Conflict'] == 1].shape[0])
print("Não conflito:", df_victor[df_victor['Conflict'] == 0].shape[0])
print("Indeterminado:", df_victor[df_victor['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES VICTOR:
# Aborto:
# Conflito: 208
# Não conflito: 178
# Indeterminado: 14

# %%
#Distribuição de conflitos por classes CAIO

#Separando as classes
reply_caio = df_caio[df_caio['Class'] == 1]
quote_caio = df_caio[df_caio['Class'] == 2]
original_caio = df_caio[df_caio['Class'] == 0]
print("Distribuição de conflitos por classes CAIO:")
print("Replys anotados:", reply_caio.shape[0])
print("Conflitos:", reply_caio[reply_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_caio[reply_caio['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_caio.shape[0])
print("Conflitos:", quote_caio[quote_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_caio[quote_caio['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_caio.shape[0])
print("Conflitos:", original_caio[original_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", original_caio[original_caio['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes CAIO:
# Replys anotados: 82
# Conflitos: 50
# Não conflitos: 31
#
# Quote anotados: 55
# Conflitos: 33
# Não conflitos: 21
#
# Originals anotados: 263
# Conflitos: 114
# Não conflitos: 135

# %%
#Distribuição de conflitos por classes VICTOR

#Separando as classes
reply_victor = df_victor[df_victor['Class'] == 1]
quote_victor = df_victor[df_victor['Class'] == 2]
original_victor = df_victor[df_victor['Class'] == 0]
print("Distribuição de conflitos por classes VICTOR:")
print("Replys anotados:", reply_victor.shape[0])
print("Conflitos:", reply_victor[reply_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_victor[reply_victor['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_victor.shape[0])
print("Conflitos:", quote_victor[quote_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_victor[quote_victor['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_victor.shape[0])
print("Conflitos:", original_victor[original_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", original_victor[original_victor['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes VICTOR:
# Replys anotados: 82
# Conflitos: 48
# Não conflitos: 34
#
# Quote anotados: 55
# Conflitos: 32
# Não conflitos: 22
#
# Originals anotados: 263
# Conflitos: 128
# Não conflitos: 122

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_caio[reply_caio['Conflict'] == 1].shape[0],
    quote_caio[quote_caio['Conflict'] == 1].shape[0],
    original_caio[original_caio['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_caio[reply_caio['Conflict'] == 0].shape[0],
    quote_caio[quote_caio['Conflict'] == 0].shape[0],
    original_caio[original_caio['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_caio[reply_caio['Conflict'] == -1].shape[0],
    quote_caio[quote_caio['Conflict'] == -1].shape[0],
    original_caio[original_caio['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class CAIO")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_victor[reply_victor['Conflict'] == 1].shape[0],
    quote_victor[quote_victor['Conflict'] == 1].shape[0],
    original_victor[original_victor['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_victor[reply_victor['Conflict'] == 0].shape[0],
    quote_victor[quote_victor['Conflict'] == 0].shape[0],
    original_victor[original_victor['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_victor[reply_victor['Conflict'] == -1].shape[0],
    quote_victor[quote_victor['Conflict'] == -1].shape[0],
    original_victor[original_victor['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class VICTOR")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# Previsoes incorretas CAIO:
df_inc_caio = df_caio[(df_caio['P(Conflict)'] > 0.5) & (df_caio['Conflict'] != 1)]
df_inc_caio.shape
# Out:
# (184, 6)

# %%
# Previsoes incorretas VICTOR:
df_inc_victor = df_victor[(df_victor['P(Conflict)'] > 0.5) & (df_victor['Conflict'] != 1)]
df_inc_victor.shape
# Out:
# (175, 6)

# %%
#Erros por classe de tweet CAIO
print("Erros por classe de tweet:")
print("Replys:", df_inc_caio[df_inc_caio['Class'] == 1].shape[0])
print("Quotes:", df_inc_caio[df_inc_caio['Class'] == 2].shape[0])
print("Originals:", df_inc_caio[df_inc_caio['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 26
# Quotes: 16
# Originals: 142

# %%
#Erros por classe de tweet VICTOR
print("Erros por classe de tweet:")
print("Replys:", df_inc_victor[df_inc_victor['Class'] == 1].shape[0])
print("Quotes:", df_inc_victor[df_inc_victor['Class'] == 2].shape[0])
print("Originals:", df_inc_victor[df_inc_victor['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 29
# Quotes: 17
# Originals: 129

# %%
#Organizando classificações de conflitos de Caio e Victor em um unico DF
df = df_caio.drop('Conflict', axis = 1)
df['Conflict_Caio'] = df_caio['Conflict']
df['Conflict_Victor'] = df_victor['Conflict']

# %%
df
# Out:
#                                                tweet_1  \
# 0    Estamos em 2020 século 21, as mulheres ainda n...
# 1                     #AbortoNao Jamais ! Sim a vida .
# 2    #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3    Alguém pode me explicar quem levantou a pauta ...
# 4    Aborto não é método contraceptivo!antes de esc...
# ..                                                 ...
# 395  mano pq tem uma tag contra aborto nos trends e...
# 396  Coleguinha que apoia essa maldita tag do #Abor...
# 397  #AbortoNao  Gente uma criança não é um castigo...
# 398  ser isso for legalizado ninguém vai ser obriga...
# 399       Respeite a vida Desde a concepção #AbortoNao
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1    Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2    vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3    Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 4    Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# ..                                                 ...    ...            ...
# 395  tem q ser muito babaca pra ser contra o aborto...      0       0.042105
# 396  Já que  defende tanto o aborto ,acho que o err...      0       0.042106
# 397  a mulher quer abortar, vcs não deixam as gays ...      0       0.042113
# 398  ABORTO NÃO!!! Vc não tem direito sobre a VIDA!...      0       0.042124
# 399  toma no cu todo mundo, o útero é da mina se el...      0       0.042142
#
#      P(Conflict)  Conflict_Caio  Conflict_Victor
# 0       0.970027              0                0
# 1       0.964738              1                1
# 2       0.964286              0                0
# 3       0.961901              0                1
# 4       0.961731              1                1
# ..           ...            ...              ...
# 395     0.957895              0                0
# 396     0.957894              0                0
# 397     0.957887              0                0
# 398     0.957876              1                1
# 399     0.957858              1                1
#
# [400 rows x 7 columns]

# %%
df.to_csv("aborto_induzido_classificado.csv", index=False, encoding="utf-8")
files.download("aborto_induzido_classificado.csv")

# %% [markdown]
# # **Criando Dataset das divergencias**

# %%
div = df_caio.iloc[idx_diff].drop('Conflict', axis=1)
div['Conflict_caio'] = df_caio['Conflict'].iloc[idx_diff].astype(int)
div['Conflict_victor'] = df_victor['Conflict'].iloc[idx_diff].astype(int)
div['Conflict'] = np.nan

# %%
div.shape
# Out:
# (60, 8)

# %%
div
# Out:
#                                                tweet_1  \
# 3    Alguém pode me explicar quem levantou a pauta ...
# 7                        #AbortoSim ELAS QUE DECIDEM !
# 14   “Se somos escravos do ontem, somos donos de no...
# 15   Vamos ser coerentes, não faz sentido tirar a v...
# 18   Sem condições e acaba abandonando na rua, você...
# 29                    #AbortoNao pela vida e para vida
# 31              Basta de tanto sofrimento.  #AbortoNAO
# 33   Fatos sobre o aborto no Brasil e no mundo que ...
# 49   hoje tá foda viu essas # de monarquiaja e abor...
# 50                           Direito à vida #AbortoNao
# 56   da vida dessa menina que quando chegar em casa...
# 57   Quardar o pau e fechar as pernas também ajuda,...
# 344  gente é tão ridículo entrar na tag e só ver ho...      0       0.040199
# 346  Fala a verdade vc nem se importa tanto assim. ...      0       0.040339
# 353  #abortosim se não tem útero, não de opinião. E...      0       0.040651
# 356  Pessoal, levantaram a #AbortoNao. É explícito ...      0       0.040703
# 364  Se você se diz católico e pró aborto, saiba qu...      0       0.041140
# 366  vão tomar no cu de vcs que é com essa hashtag ...      0       0.041183
# 367  Você que é contra o aborto, o que sente quando...      0       0.041211
# 371  Se vc é cristão, pq invés de subir a #AbortoNA...      0       0.041381
# 374  Vocês não estão prontos para está conversa, e ...      0       0.041412
# 377  ai gente, desnecessário #abortosim e #abortonã...      0       0.041552
# 383  a galera do #AbortoNao é muito engraçadaKFKDKD...      0       0.041879
#
#      P(Conflict)  Conflict_caio  Conflict_victor  Conflict
# 3       0.961901              0                1       NaN
# 7       0.958238             -1                0       NaN
# 14      0.954788              1                0       NaN
# 15      0.954625              1                0       NaN
# 18      0.952196              1                0       NaN
# 29      0.943364              1                0       NaN
# 31      0.942628              1                0       NaN
# 33      0.941685              1                0       NaN
# 49      0.923704             -1                0       NaN
# 50      0.923447              1                0       NaN
# 56      0.919473              1                0       NaN
# 57      0.919315              0               -1       NaN
# 58      0.918655              1                0       NaN
# 82      0.881651              1                0       NaN
# 85      0.878267              0                1       NaN
# 87      0.874087              0               -1       NaN
# 88      0.872783              1                0       NaN
# 92      0.868336              1                0       NaN
# 106     0.830758              0                1       NaN
# 110     0.825839              0                1       NaN
# 113     0.813729             -1                1       NaN
# 116     0.805360              0               -1       NaN
# 119     0.790889             -1                0       NaN
# 128     0.744461              0                1       NaN
# 136     0.715341              1                0       NaN
# 137     0.712912              0                1       NaN
# 139     0.704634              0               -1       NaN
# 143     0.686017              0                1       NaN
# 166     0.558365             -1                1       NaN
# 172     0.494926              0                1       NaN
# 177     0.439023             -1                1       NaN
# 186     0.376052             -1                0       NaN
# 191     0.321655             -1                0       NaN
# 216     0.968067              0                1       NaN
# 226     0.967262              0               -1       NaN
# 231     0.966341              0               -1       NaN
# 252     0.964520              1                0       NaN
# 265     0.963544              0                1       NaN
# 285     0.962168              0                1       NaN
# 294     0.961831              1                0       NaN
# 296     0.961767              1               -1       NaN
# 308     0.961354              0                1       NaN
# 309     0.961262              0                1       NaN
# 318     0.960938              1               -1       NaN
# 321     0.960907              0               -1       NaN
# 327     0.960689              0               -1       NaN
# 337     0.960324              0                1       NaN
# 340     0.960056             -1                1       NaN
# 341     0.959958              0                1       NaN
# 344     0.959801              0                1       NaN
# 346     0.959661              0                1       NaN
# 353     0.959349              0                1       NaN
# 356     0.959297             -1                0       NaN
# 364     0.958860             -1                0       NaN
# 366     0.958817              0                1       NaN
# 367     0.958789              0                1       NaN
# 371     0.958619             -1                1       NaN
# 374     0.958588              0                1       NaN
# 377     0.958448              0                1       NaN
# 383     0.958121              0                1       NaN

# %%
div_aborto_final = div.drop(columns=['Conflict_caio', 'Conflict_victor'])
div_aborto_final
# Out:
#                                                tweet_1  \
# 308  STF de que modo vc pode ferrar com todo mundo ...      0       0.038646
# 309  Aborto legalizado e questão de saúde pública e...      0       0.038738
# 318  #AbortoSim Pra você que quer aborto, não vai ter.      0       0.039062
# 321  "Se você é homem, você não pode falar de abort...      0       0.039093
# 327  sério cara me dá um ódio muito grande imaginar...      0       0.039311
# 337  #AbortoSim  "Ela é quem tem que decidir" Claro...      0       0.039676
# 340  sabe por que #AbortoSim? porque se a mulher br...      0       0.039944
# 341  Antes de usar argumentos de q aborto é para "l...      0       0.040042
# 344  gente é tão ridículo entrar na tag e só ver ho...      0       0.040199
# 346  Fala a verdade vc nem se importa tanto assim. ...      0       0.040339
# 353  #abortosim se não tem útero, não de opinião. E...      0       0.040651
# 356  Pessoal, levantaram a #AbortoNao. É explícito ...      0       0.040703
# 364  Se você se diz católico e pró aborto, saiba qu...      0       0.041140
# 366  vão tomar no cu de vcs que é com essa hashtag ...      0       0.041183
# 367  Você que é contra o aborto, o que sente quando...      0       0.041211
# 371  Se vc é cristão, pq invés de subir a #AbortoNA...      0       0.041381
# 374  Vocês não estão prontos para está conversa, e ...      0       0.041412
# 377  ai gente, desnecessário #abortosim e #abortonã...      0       0.041552
# 383  a galera do #AbortoNao é muito engraçadaKFKDKD...      0       0.041879
#
#      P(Conflict)  Conflict
# 3       0.961901       NaN
# 7       0.958238       NaN
# 14      0.954788       NaN
# 15      0.954625       NaN
# 18      0.952196       NaN
# 29      0.943364       NaN
# 31      0.942628       NaN
# 33      0.941685       NaN
# 49      0.923704       NaN
# 50      0.923447       NaN
# 56      0.919473       NaN
# 57      0.919315       NaN
# 58      0.918655       NaN
# 82      0.881651       NaN
# 85      0.878267       NaN
# 87      0.874087       NaN
# 88      0.872783       NaN
# 92      0.868336       NaN
# 106     0.830758       NaN
# 110     0.825839       NaN
# 113     0.813729       NaN
# 116     0.805360       NaN
# 119     0.790889       NaN
# 128     0.744461       NaN
# 136     0.715341       NaN
# 137     0.712912       NaN
# 139     0.704634       NaN
# 143     0.686017       NaN
# 166     0.558365       NaN
# 172     0.494926       NaN
# 177     0.439023       NaN
# 186     0.376052       NaN
# 191     0.321655       NaN
# 216     0.968067       NaN
# 226     0.967262       NaN
# 231     0.966341       NaN
# 252     0.964520       NaN
# 265     0.963544       NaN
# 285     0.962168       NaN
# 294     0.961831       NaN
# 296     0.961767       NaN
# 308     0.961354       NaN
# 309     0.961262       NaN
# 318     0.960938       NaN
# 321     0.960907       NaN
# 327     0.960689       NaN
# 337     0.960324       NaN
# 340     0.960056       NaN
# 341     0.959958       NaN
# 344     0.959801       NaN
# 346     0.959661       NaN
# 353     0.959349       NaN
# 356     0.959297       NaN
# 364     0.958860       NaN
# 366     0.958817       NaN
# 367     0.958789       NaN
# 371     0.958619       NaN
# 374     0.958588       NaN
# 377     0.958448       NaN
# 383     0.958121       NaN

# %%
div_aborto_final.to_csv("divergencias_aborto_induzido.csv", index=False, encoding="utf-8")
files.download("divergencias_aborto_induzido.csv")

# %% [markdown]
# # **Criando Dataset das Convergencias**

# %%
conv_aborto = df_caio.drop(index=idx_diff, errors='ignore')
conv_aborto.shape
# Out:
# (340, 6)

# %%
conv_aborto
# Out:
#                                                tweet_1  \
# 0    Estamos em 2020 século 21, as mulheres ainda n...
# 1                     #AbortoNao Jamais ! Sim a vida .
# 2    #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 4    Aborto não é método contraceptivo!antes de esc...
# 5    Pelo simples fato de que matar uma vida humana...
# ..                                                 ...
# 395  mano pq tem uma tag contra aborto nos trends e...
# 396  Coleguinha que apoia essa maldita tag do #Abor...
# 397  #AbortoNao  Gente uma criança não é um castigo...
# 398  ser isso for legalizado ninguém vai ser obriga...
# 399       Respeite a vida Desde a concepção #AbortoNao
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1    Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2    vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 4    Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# 5    @ Vida é a partir do embrião.E embrião é vida....      1       0.040479
# ..                                                 ...    ...            ...
# 395  tem q ser muito babaca pra ser contra o aborto...      0       0.042105
# 396  Já que  defende tanto o aborto ,acho que o err...      0       0.042106
# 397  a mulher quer abortar, vcs não deixam as gays ...      0       0.042113
# 398  ABORTO NÃO!!! Vc não tem direito sobre a VIDA!...      0       0.042124
# 399  toma no cu todo mundo, o útero é da mina se el...      0       0.042142
#
#      P(Conflict)  Conflict
# 0       0.970027         0
# 1       0.964738         1
# 2       0.964286         0
# 4       0.961731         1
# 5       0.959521         1
# ..           ...       ...
# 395     0.957895         0
# 396     0.957894         0
# 397     0.957887         0
# 398     0.957876         1
# 399     0.957858         1
#
# [340 rows x 6 columns]

# %%
#juntando anotações do professor (QUANDO ELE ANOTAR)
#adicionando as classificações do professor
file_class_prof = "1Nl7KAvC4kwEEmBskSZVEaPsdYzACoafh"
url = f"https://drive.google.com/uc?id={file_class_prof}"
gdown.download(url, "class_prof.csv", quiet=False)
df_class_prof = pd.read_csv ("class_prof.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Nl7KAvC4kwEEmBskSZVEaPsdYzACoafh
# To: /content/class_prof.csv
# 100%|██████████| 5.27k/5.27k [00:00<00:00, 12.7MB/s]

# %%
df_class_prof
# Out:
#                                               tweet_1  \
# 0   Alguém pode me explicar quem levantou a pauta ...
# 1                       #AbortoSim ELAS QUE DECIDEM !
# 2   “Se somos escravos do ontem, somos donos de no...
# 3   Vamos ser coerentes, não faz sentido tirar a v...
# 4   Sem condições e acaba abandonando na rua, você...
# 5                    #AbortoNao pela vida e para vida
# 6              Basta de tanto sofrimento.  #AbortoNAO
# 7   Fatos sobre o aborto no Brasil e no mundo que ...
# 8   hoje tá foda viu essas # de monarquiaja e abor...
# 9                           Direito à vida #AbortoNao
# 10  da vida dessa menina que quando chegar em casa...
# 11  Quardar o pau e fechar as pernas também ajuda,...
# 12  Aborto é ASSASSINATO não tem o que discutir, n...
# 13  Aborto não devia ser nem discutido. O feto nem...
# 14           #AbortoSim só vcs darem o cu suas porras
# 15  #AbortoSim  não é porque sou a favor que vou a...
# 16                       Sou mulher e digo #AbortoNao
# 17  A menos que você esteja grávida, #AbortoNao é ...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 1   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 2   o engraçado é que quando você entra no “aborto...      0       0.045212
# 3   #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 4   Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 5       n sei pq tão discutindo isso porém #AbortoSim      0       0.056636
# 6   A partir do momento que várias mulheres morrem...      0       0.057372
# 7   na sua opinião a cabeça de alguém que aborta v...      2       0.058315
# 8   Eu olhando o perfil dos acéfalos que levantam ...      0       0.076296
# 9   não podia ir dormir sem tentar subir essa # #A...      0       0.076553
# 10  Entendo e sinto pela garota, mas não resolvemo...      1       0.080527
# 11  Só tem macho nessa #AbortoNao , omeee se aquie...      0       0.080685
# 12  Uma mulher abortista, poderia ter sido abortad...      0       0.081345
# 13  Homens não têm nem direito de opinar sobre iss...      1       0.118349
# 14  #AbortoSim se não como é que a nossa Pepsi gel...      0       0.121733
# 15  #AbortoNunca eu vejo agora o pessoal subindo a...      0       0.125913
# 16                 ok eu sou mulher e digo #AbortoSim      1       0.127217
# 17  Pessoas que não conseguem entender que crença ...      2       0.131664
#
#     P(Conflict)  Conflict
# 0      0.961901         1
# 1      0.958238         0
# 2      0.954788        -1
# 3      0.954625        -1
# 4      0.952196         0
# 5      0.943364         0
# 6      0.942628         0
# 7      0.941685         0
# 8      0.923704         1
# 9      0.923447         0
# 10     0.919473        -1
# 11     0.919315        -1
# 12     0.918655         0
# 13     0.881651         0
# 14     0.878267         0
# 15     0.874087         1
# 16     0.872783        -1
# 17     0.868336         0

# %%
df_desempate = div.merge(df_class_prof, on=['tweet_1', 'tweet_2'], how='inner')
df_desempate = df_desempate.drop(columns=['Conflict_x', 'Class_y', 'P(NoConflict)_y', 'P(Conflict)_y'])
df_desempate = df_desempate.rename(columns={'Class_x': 'Class', 'P(NoConflict)_x': 'P(NoConflict)', 'P(Conflict)_x': 'P(Conflict)', 'Conflict_y': 'Conflict_prof' })
df_desempate
# Out:
#                                               tweet_1  \
# 0   Alguém pode me explicar quem levantou a pauta ...
# 1                       #AbortoSim ELAS QUE DECIDEM !
# 2   “Se somos escravos do ontem, somos donos de no...
# 3   Vamos ser coerentes, não faz sentido tirar a v...
# 4   Sem condições e acaba abandonando na rua, você...
# 5                    #AbortoNao pela vida e para vida
# 6              Basta de tanto sofrimento.  #AbortoNAO
# 7   Fatos sobre o aborto no Brasil e no mundo que ...
# 8   hoje tá foda viu essas # de monarquiaja e abor...
# 9                           Direito à vida #AbortoNao
# 10  da vida dessa menina que quando chegar em casa...
# 11  Quardar o pau e fechar as pernas também ajuda,...
# 12  Aborto é ASSASSINATO não tem o que discutir, n...
# 13  Aborto não devia ser nem discutido. O feto nem...
# 14           #AbortoSim só vcs darem o cu suas porras
# 15  #AbortoSim  não é porque sou a favor que vou a...
# 16                       Sou mulher e digo #AbortoNao
# 17  A menos que você esteja grávida, #AbortoNao é ...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 1   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 2   o engraçado é que quando você entra no “aborto...      0       0.045212
# 3   #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 4   Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 5       n sei pq tão discutindo isso porém #AbortoSim      0       0.056636
# 6   A partir do momento que várias mulheres morrem...      0       0.057372
# 7   na sua opinião a cabeça de alguém que aborta v...      2       0.058315
# 8   Eu olhando o perfil dos acéfalos que levantam ...      0       0.076296
# 9   não podia ir dormir sem tentar subir essa # #A...      0       0.076553
# 10  Entendo e sinto pela garota, mas não resolvemo...      1       0.080527
# 11  Só tem macho nessa #AbortoNao , omeee se aquie...      0       0.080685
# 12  Uma mulher abortista, poderia ter sido abortad...      0       0.081345
# 13  Homens não têm nem direito de opinar sobre iss...      1       0.118349
# 14  #AbortoSim se não como é que a nossa Pepsi gel...      0       0.121733
# 15  #AbortoNunca eu vejo agora o pessoal subindo a...      0       0.125913
# 16                 ok eu sou mulher e digo #AbortoSim      1       0.127217
# 17  Pessoas que não conseguem entender que crença ...      2       0.131664
#
#     P(Conflict)  Conflict_caio  Conflict_victor  Conflict_prof
# 0      0.961901              0                1              1
# 1      0.958238             -1                0              0
# 2      0.954788              1                0             -1
# 3      0.954625              1                0             -1
# 4      0.952196              1                0              0
# 5      0.943364              1                0              0
# 6      0.942628              1                0              0
# 7      0.941685              1                0              0
# 8      0.923704             -1                0              1
# 9      0.923447              1                0              0
# 10     0.919473              1                0             -1
# 11     0.919315              0               -1             -1
# 12     0.918655              1                0              0
# 13     0.881651              1                0              0
# 14     0.878267              0                1              0
# 15     0.874087              0               -1              1
# 16     0.872783              1                0             -1
# 17     0.868336              1                0              0

# %%
def resolver_conflito(row):
    prof = row['Conflict_prof']
    caio = row['Conflict_caio']
    victor = row['Conflict_victor']

    if prof == caio or prof == victor:
        return prof
    else:
        return -1

df_desempate['Conflict'] = df_desempate.apply(resolver_conflito, axis=1)

# %%
df_desempate
# Out:
#                                               tweet_1  \
# 0   Alguém pode me explicar quem levantou a pauta ...
# 1                       #AbortoSim ELAS QUE DECIDEM !
# 2   “Se somos escravos do ontem, somos donos de no...
# 3   Vamos ser coerentes, não faz sentido tirar a v...
# 4   Sem condições e acaba abandonando na rua, você...
# 5                    #AbortoNao pela vida e para vida
# 6              Basta de tanto sofrimento.  #AbortoNAO
# 7   Fatos sobre o aborto no Brasil e no mundo que ...
# 8   hoje tá foda viu essas # de monarquiaja e abor...
# 9                           Direito à vida #AbortoNao
# 10  da vida dessa menina que quando chegar em casa...
# 11  Quardar o pau e fechar as pernas também ajuda,...
# 12  Aborto é ASSASSINATO não tem o que discutir, n...
# 13  Aborto não devia ser nem discutido. O feto nem...
# 14           #AbortoSim só vcs darem o cu suas porras
# 15  #AbortoSim  não é porque sou a favor que vou a...
# 16                       Sou mulher e digo #AbortoNao
# 17  A menos que você esteja grávida, #AbortoNao é ...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 1   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 2   o engraçado é que quando você entra no “aborto...      0       0.045212
# 3   #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 4   Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 5       n sei pq tão discutindo isso porém #AbortoSim      0       0.056636
# 6   A partir do momento que várias mulheres morrem...      0       0.057372
# 7   na sua opinião a cabeça de alguém que aborta v...      2       0.058315
# 8   Eu olhando o perfil dos acéfalos que levantam ...      0       0.076296
# 9   não podia ir dormir sem tentar subir essa # #A...      0       0.076553
# 10  Entendo e sinto pela garota, mas não resolvemo...      1       0.080527
# 11  Só tem macho nessa #AbortoNao , omeee se aquie...      0       0.080685
# 12  Uma mulher abortista, poderia ter sido abortad...      0       0.081345
# 13  Homens não têm nem direito de opinar sobre iss...      1       0.118349
# 14  #AbortoSim se não como é que a nossa Pepsi gel...      0       0.121733
# 15  #AbortoNunca eu vejo agora o pessoal subindo a...      0       0.125913
# 16                 ok eu sou mulher e digo #AbortoSim      1       0.127217
# 17  Pessoas que não conseguem entender que crença ...      2       0.131664
#
#     P(Conflict)  Conflict_caio  Conflict_victor  Conflict_prof  Conflict
# 0      0.961901              0                1              1         1
# 1      0.958238             -1                0              0         0
# 2      0.954788              1                0             -1        -1
# 3      0.954625              1                0             -1        -1
# 4      0.952196              1                0              0         0
# 5      0.943364              1                0              0         0
# 6      0.942628              1                0              0         0
# 7      0.941685              1                0              0         0
# 8      0.923704             -1                0              1        -1
# 9      0.923447              1                0              0         0
# 10     0.919473              1                0             -1        -1
# 11     0.919315              0               -1             -1        -1
# 12     0.918655              1                0              0         0
# 13     0.881651              1                0              0         0
# 14     0.878267              0                1              0         0
# 15     0.874087              0               -1              1        -1
# 16     0.872783              1                0             -1        -1
# 17     0.868336              1                0              0         0

# %%
df_desempate = df_desempate.drop(columns=['Conflict_caio', 'Conflict_victor', 'Conflict_prof'])
df_desempate
# Out:
#                                               tweet_1  \
# 0   Alguém pode me explicar quem levantou a pauta ...
# 1                       #AbortoSim ELAS QUE DECIDEM !
# 2   “Se somos escravos do ontem, somos donos de no...
# 3   Vamos ser coerentes, não faz sentido tirar a v...
# 4   Sem condições e acaba abandonando na rua, você...
# 5                    #AbortoNao pela vida e para vida
# 6              Basta de tanto sofrimento.  #AbortoNAO
# 7   Fatos sobre o aborto no Brasil e no mundo que ...
# 8   hoje tá foda viu essas # de monarquiaja e abor...
# 9                           Direito à vida #AbortoNao
# 10  da vida dessa menina que quando chegar em casa...
# 11  Quardar o pau e fechar as pernas também ajuda,...
# 12  Aborto é ASSASSINATO não tem o que discutir, n...
# 13  Aborto não devia ser nem discutido. O feto nem...
# 14           #AbortoSim só vcs darem o cu suas porras
# 15  #AbortoSim  não é porque sou a favor que vou a...
# 16                       Sou mulher e digo #AbortoNao
# 17  A menos que você esteja grávida, #AbortoNao é ...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0   Se vc vem opinar numa tag feminina sendo contr...      0       0.038099
# 1   Ai que inferno, é vc que está com o feto no út...      0       0.041762
# 2   o engraçado é que quando você entra no “aborto...      0       0.045212
# 3   #AbortoSim  Mas quanta pretensão  Vocês nem sa...      0       0.045375
# 4   Então vc acha q a fome, o frio, a pobreza se r...      1       0.047804
# 5       n sei pq tão discutindo isso porém #AbortoSim      0       0.056636
# 6   A partir do momento que várias mulheres morrem...      0       0.057372
# 7   na sua opinião a cabeça de alguém que aborta v...      2       0.058315
# 8   Eu olhando o perfil dos acéfalos que levantam ...      0       0.076296
# 9   não podia ir dormir sem tentar subir essa # #A...      0       0.076553
# 10  Entendo e sinto pela garota, mas não resolvemo...      1       0.080527
# 11  Só tem macho nessa #AbortoNao , omeee se aquie...      0       0.080685
# 12  Uma mulher abortista, poderia ter sido abortad...      0       0.081345
# 13  Homens não têm nem direito de opinar sobre iss...      1       0.118349
# 14  #AbortoSim se não como é que a nossa Pepsi gel...      0       0.121733
# 15  #AbortoNunca eu vejo agora o pessoal subindo a...      0       0.125913
# 16                 ok eu sou mulher e digo #AbortoSim      1       0.127217
# 17  Pessoas que não conseguem entender que crença ...      2       0.131664
#
#     P(Conflict)  Conflict
# 0      0.961901         1
# 1      0.958238         0
# 2      0.954788        -1
# 3      0.954625        -1
# 4      0.952196         0
# 5      0.943364         0
# 6      0.942628         0
# 7      0.941685         0
# 8      0.923704        -1
# 9      0.923447         0
# 10     0.919473        -1
# 11     0.919315        -1
# 12     0.918655         0
# 13     0.881651         0
# 14     0.878267         0
# 15     0.874087        -1
# 16     0.872783        -1
# 17     0.868336         0

# %%
conv_aborto = pd.concat([conv_aborto, df_desempate], ignore_index=True, axis = 0)
conv_aborto
# Out:
#                                                tweet_1  \
# 0    Estamos em 2020 século 21, as mulheres ainda n...
# 1                     #AbortoNao Jamais ! Sim a vida .
# 2    #AbortoNunca ENTENDAM quando a pessoa é #Abort...
# 3    Aborto não é método contraceptivo!antes de esc...
# 4    Pelo simples fato de que matar uma vida humana...
# ..                                                 ...
# 353  Aborto não devia ser nem discutido. O feto nem...
# 354           #AbortoSim só vcs darem o cu suas porras
# 355  #AbortoSim  não é porque sou a favor que vou a...
# 356                       Sou mulher e digo #AbortoNao
# 357  A menos que você esteja grávida, #AbortoNao é ...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0    Qd vc abre a hastag #AbortoNao, a unica coisa ...      0       0.029973
# 1    Vc é contra o aborto por se declarar pró vida,...      0       0.035262
# 2    vcs falam #AbortoNao como se existisse um méto...      0       0.035714
# 3    Vai caça o que fazer e deixa as mulheres escol...      1       0.038269
# 4    @ Vida é a partir do embrião.E embrião é vida....      1       0.040479
# ..                                                 ...    ...            ...
# 353  Homens não têm nem direito de opinar sobre iss...      1       0.118349
# 354  #AbortoSim se não como é que a nossa Pepsi gel...      0       0.121733
# 355  #AbortoNunca eu vejo agora o pessoal subindo a...      0       0.125913
# 356                 ok eu sou mulher e digo #AbortoSim      1       0.127217
# 357  Pessoas que não conseguem entender que crença ...      2       0.131664
#
#      P(Conflict)  Conflict
# 0       0.970027         0
# 1       0.964738         1
# 2       0.964286         0
# 3       0.961731         1
# 4       0.959521         1
# ..           ...       ...
# 353     0.881651         0
# 354     0.878267         0
# 355     0.874087        -1
# 356     0.872783        -1
# 357     0.868336         0
#
# [358 rows x 6 columns]

# %%
conv_aborto.to_csv("convergencias_aborto_induzido.csv", index=False, encoding="utf-8")
files.download("convergencias_aborto_induzido.csv")

# %% [markdown]
# # **Criando dataset dos não anotados**

# %%
df_remaining
# Out:
#                                                  tweet_1  \
# 400    eu não consigo entender mulher que é #AbortoNa...
# 401    Nenhum método contraceptivos é 100% seguro log...
# 402    Ninguém tem direito de se meter no corpo alhei...
# 403      Cabe a mulher decidir o corpo é dela #AbortoSim
# 404    #AbortoNAO Os menos culpados não devem ter sua...
# ...                                                  ...
# 14244     Vamos começar a pressão ao STF já.  #AbortoNAO
# 14245  Em plena epidemia do Covid-19, o STF quer apro...
# 14246  Vamos subir #AbortoNao .  STF quer aprovar med...
# 14247     Vamos começar a pressão ao STF já.  #AbortoNAO
# 14248     Vamos começar a pressão ao STF já.  #AbortoNAO
#
#                                                  tweet_2  Class  \
# 400    o povo do #AbortoNao eh um banco de hipocritas...      0
# 401    @ Errado, se fosse assim as mães poderiam mata...      1
# 402     STF vocês não devem legalizar o crime #AbortoNao      0
# 403    Que porra eh essa de #AbortoNao mano? Pelo amo...      0
# 404    vcs q sao contra o o aborto porem comem ovo, s...      0
# ...                                                  ...    ...
# 14244                 Podemos abortar o STF?  #AbortoNAO      1
# 14245                               #STF LIXO #AbortoNao      1
# 14246       Aborto Não. #AbortoNao  #STFVergonhaNacional      2
# 14247                            Com certeza! #AbortoNAO      1
# 14248                            STF CANALHAS #AbortoNAO      1
#
#        P(NoConflict)  P(Conflict)  Conflict
# 400         0.042154     0.957846       NaN
# 401         0.042214     0.957786       NaN
# 402         0.042232     0.957768       NaN
# 403         0.042258     0.957742       NaN
# 404         0.042262     0.957738       NaN
# ...              ...          ...       ...
# 14244       0.996241     0.003759       NaN
# 14245       0.996319     0.003681       NaN
# 14246       0.996320     0.003680       NaN
# 14247       0.996372     0.003629       NaN
# 14248       0.996459     0.003541       NaN
#
# [13849 rows x 6 columns]

# %%
df_remaining.to_csv("nao_anotados_aborto_induzido.csv", index=False, encoding="utf-8")
files.download("nao_anotados_aborto_induzido.csv")
