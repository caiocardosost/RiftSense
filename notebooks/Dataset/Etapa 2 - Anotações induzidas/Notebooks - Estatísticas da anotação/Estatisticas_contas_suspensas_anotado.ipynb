# %% [markdown]
# # **Projeto de Graduação em Computação II [2026-Q1]**
#
# Universidade Federal do ABC
#
# Orientador Carlos da Silva dos Santos

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# Caio Cardoso Dos Santos - RA: 11202021632
#
# Victor Ravazio de Lima - RA: 11201920941

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %%
# modulo para importar dataset a partir de um link
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
#Bibliotecas
import pandas as pd
import numpy as np
from google.colab import files
import gdown
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
#Variaveis de controle
anotado = 400
# num_replys_anotados = 150
# num_quotes_anotados = 150
# num_originals_anotados = 150

# %%
# baixando dataset para o collab
import gdown

file_class_caio = "1Xg1GIzS0EjcXHU5QeWpz66VgSThqrLvg"
file_class_victor = "1yMqv-9S3-zSZuvwNUZWvfC5x_W_lXVlk"
url_1 = f"https://drive.google.com/uc?id={file_class_caio}"
url_2 = f"https://drive.google.com/uc?id={file_class_victor}"

gdown.download(url_1, "contas_suspensas_anotado_caio.csv", quiet=False)
gdown.download(url_2, "contas_suspensas_anotado_victor.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Xg1GIzS0EjcXHU5QeWpz66VgSThqrLvg
# To: /content/contas_suspensas_anotado_caio.csv
# 100%|██████████| 10.1M/10.1M [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yMqv-9S3-zSZuvwNUZWvfC5x_W_lXVlk
# To: /content/contas_suspensas_anotado_victor.csv
# 100%|██████████| 10.1M/10.1M [00:00<00:00, 21.5MB/s]
# 'contas_suspensas_anotado_victor.csv'

# %%
#carregando o dataset
df_caio = pd.read_csv ("contas_suspensas_anotado_caio.csv")
df_victor = pd.read_csv ("contas_suspensas_anotado_victor.csv")

# %%
#numero total de instancias no dataset
df_caio.shape
# Out:
# (30665, 6)

# %%
#numero total de instancias no dataset
df_victor.shape
# Out:
# (30665, 6)

# %%
df_caio.head(20)
# Out:
#                                               tweet_1  \
# 0   Vocês também estão sentindo que o clima aqui n...
# 1   Vocês também estão sentindo que o clima aqui n...
# 2   Vocês também estão sentindo que o clima aqui n...
# 3   Vocês também estão sentindo que o clima aqui n...
# 4   Vocês também estão sentindo que o clima aqui n...
# 5   Vocês também estão sentindo que o clima aqui n...
# 6   Vocês também estão sentindo que o clima aqui n...
# 7   Po, tem um monte de página no twt que propaga ...
# 8   Vocês também estão sentindo que o clima aqui n...
# 9   Vocês também estão sentindo que o clima aqui n...
# 10  Cês tão ligados que isso aqui é nível China de...
# 11  O que vc pensa de um edital de cultura com cen...
# 12  Caralho, mas o 2 é o melhor é como se tivesse ...
# 13  Hoje são   Allan dos Santos Bernardo Kuster Ed...
# 14  Caio, sério que vc está comemorando censura? D...
# 15  Errado, se a lei disser que é proibido falar m...
# 16  Já é hora, já passou da hora de acabar com ess...
# 17  Vocês também estão sentindo que o clima aqui n...
# 18  Os idiotas que comemoram a censura nem imagina...
# 19  A turma que tem medo do Presidente BOLSONARO a...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0                            A Sra curte uma censura?      1       0.033065
# 1   Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2      Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3          Saudade de uma censura, não é minha filha?      1       0.039592
# 4   Todo bom comunista comemora censura, depois sa...      1       0.043954
# 5        Incrível como comunista gosta de uma censura      1       0.044957
# 6              Comemorando censura, é muito tosca msm      1       0.047849
# 7   Repito:  Não é censura qndo vc já foi avisado,...      1       0.048623
# 8   Gente de esquerda PTRALHAS batendo palmas para...      1       0.048965
# 9   Só CÚmunistinha caviar e acéfala comemora tama...      1       0.052040
# 10  Quando a censura afeta quem eu não gosto, pode...      1       0.055252
# 11          Te decide, é a favor ou contra a censura.      1       0.062581
# 12  mano, você quer ver o pau dos cara?? eu n gost...      1       0.066495
# 13  "censura covarde",ok, então isso quer dizer qu...      1       0.071198
# 14                                       Que censura?      1       0.072605
# 15  Acho que estamos em círculos aqui, Andi. Já vo...      1       0.073321
# 16  “Ares de censura” , vc está muito condescenden...      1       0.074162
# 17                           Bolsonaro22  Sem censura      1       0.074590
# 18                   Combater mentiras não é censura.      1       0.081891
# 19                         então  , não foi censura ?      0       0.085133
#
#     P(Conflict)  Conflict
# 0      0.966935       1.0
# 1      0.966084       1.0
# 2      0.961592       1.0
# 3      0.960408       1.0
# 4      0.956046       1.0
# 5      0.955043       1.0
# 6      0.952151       1.0
# 7      0.951377       1.0
# 8      0.951035       1.0
# 9      0.947960       1.0
# 10     0.944748       1.0
# 11     0.937419       0.0
# 12     0.933505       0.0
# 13     0.928802       1.0
# 14     0.927395       1.0
# 15     0.926680       1.0
# 16     0.925838       0.0
# 17     0.925410       0.0
# 18     0.918109       1.0
# 19     0.914867       0.0

# %%
df_victor.head(20)
# Out:
#                                               tweet_1  \
# 0   Vocês também estão sentindo que o clima aqui n...
# 1   Vocês também estão sentindo que o clima aqui n...
# 2   Vocês também estão sentindo que o clima aqui n...
# 3   Vocês também estão sentindo que o clima aqui n...
# 4   Vocês também estão sentindo que o clima aqui n...
# 5   Vocês também estão sentindo que o clima aqui n...
# 6   Vocês também estão sentindo que o clima aqui n...
# 7   Po, tem um monte de página no twt que propaga ...
# 8   Vocês também estão sentindo que o clima aqui n...
# 9   Vocês também estão sentindo que o clima aqui n...
# 10  Cês tão ligados que isso aqui é nível China de...
# 11  O que vc pensa de um edital de cultura com cen...
# 12  Caralho, mas o 2 é o melhor é como se tivesse ...
# 13  Hoje são   Allan dos Santos Bernardo Kuster Ed...
# 14  Caio, sério que vc está comemorando censura? D...
# 15  Errado, se a lei disser que é proibido falar m...
# 16  Já é hora, já passou da hora de acabar com ess...
# 17  Vocês também estão sentindo que o clima aqui n...
# 18  Os idiotas que comemoram a censura nem imagina...
# 19  A turma que tem medo do Presidente BOLSONARO a...
#
#                                               tweet_2  Class  P(NoConflict)  \
# 0                            A Sra curte uma censura?      1       0.033065
# 1   Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2      Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3          Saudade de uma censura, não é minha filha?      1       0.039592
# 4   Todo bom comunista comemora censura, depois sa...      1       0.043954
# 5        Incrível como comunista gosta de uma censura      1       0.044957
# 6              Comemorando censura, é muito tosca msm      1       0.047849
# 7   Repito:  Não é censura qndo vc já foi avisado,...      1       0.048623
# 8   Gente de esquerda PTRALHAS batendo palmas para...      1       0.048965
# 9   Só CÚmunistinha caviar e acéfala comemora tama...      1       0.052040
# 10  Quando a censura afeta quem eu não gosto, pode...      1       0.055252
# 11          Te decide, é a favor ou contra a censura.      1       0.062581
# 12  mano, você quer ver o pau dos cara?? eu n gost...      1       0.066495
# 13  "censura covarde",ok, então isso quer dizer qu...      1       0.071198
# 14                                       Que censura?      1       0.072605
# 15  Acho que estamos em círculos aqui, Andi. Já vo...      1       0.073321
# 16  “Ares de censura” , vc está muito condescenden...      1       0.074162
# 17                           Bolsonaro22  Sem censura      1       0.074590
# 18                   Combater mentiras não é censura.      1       0.081891
# 19                         então  , não foi censura ?      0       0.085133
#
#     P(Conflict)  Conflict
# 0      0.966935       1.0
# 1      0.966084       1.0
# 2      0.961592       1.0
# 3      0.960408       1.0
# 4      0.956046       1.0
# 5      0.955043       1.0
# 6      0.952151       1.0
# 7      0.951377       1.0
# 8      0.951035       1.0
# 9      0.947960       1.0
# 10     0.944748       0.0
# 11     0.937419       1.0
# 12     0.933505       0.0
# 13     0.928802       1.0
# 14     0.927395       1.0
# 15     0.926680       0.0
# 16     0.925838       0.0
# 17     0.925410       0.0
# 18     0.918109       1.0
# 19     0.914867       0.0

# %% [markdown]
# # **Analise Exploratória**

# %%
df_remaining = df_caio.iloc[anotado:,:]

# %%
# restrigindo por quantidade anotada
df_caio = df_caio.iloc[:anotado,:]
df_caio['Conflict'] = df_caio['Conflict'].astype(int) #convertendo valores para inteiros
df_victor = df_victor.iloc[:anotado,:]
df_victor['Conflict'] = df_victor['Conflict'].astype(int)

# %%
#separando por classe

# %%
df_caio
# Out:
#                                                tweet_1  \
# 0    Vocês também estão sentindo que o clima aqui n...
# 1    Vocês também estão sentindo que o clima aqui n...
# 2    Vocês também estão sentindo que o clima aqui n...
# 3    Vocês também estão sentindo que o clima aqui n...
# 4    Vocês também estão sentindo que o clima aqui n...
# ..                                                 ...
# 395  A hipocrisia das pessoas que defendem censura ...
# 396  Me faltam adjetivos pra classificar a suspensã...
# 397  Não se trata de censura, se trata de coibir di...
# 398  Dificil admitir q hj é um Grande Dia né minha ...
# 399  Esse tal de  acha que é DEUS. Duvido que ele a...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0                             A Sra curte uma censura?      1       0.033065
# 1    Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2       Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3           Saudade de uma censura, não é minha filha?      1       0.039592
# 4    Todo bom comunista comemora censura, depois sa...      1       0.043954
# ..                                                 ...    ...            ...
# 395  Só é censura quando atinge o deles Quando é do...      1       0.068635
# 396  Olha a ingenuidade. Quem é que vai censurar a ...      2       0.068722
# 397                             continua sendo censura      2       0.068751
# 398  Vamos ver quem vai comemorar a censura com “Gr...      0       0.068774
# 399  Vivi pra ver reacionário reclamando de censura...      0       0.068815
#
#      P(Conflict)  Conflict
# 0       0.966935         1
# 1       0.966084         1
# 2       0.961592         1
# 3       0.960408         1
# 4       0.956046         1
# ..           ...       ...
# 395     0.931365         0
# 396     0.931278         0
# 397     0.931249         1
# 398     0.931226         1
# 399     0.931185         1
#
# [400 rows x 6 columns]

# %%
df_victor
# Out:
#                                                tweet_1  \
# 0    Vocês também estão sentindo que o clima aqui n...
# 1    Vocês também estão sentindo que o clima aqui n...
# 2    Vocês também estão sentindo que o clima aqui n...
# 3    Vocês também estão sentindo que o clima aqui n...
# 4    Vocês também estão sentindo que o clima aqui n...
# ..                                                 ...
# 395  A hipocrisia das pessoas que defendem censura ...
# 396  Me faltam adjetivos pra classificar a suspensã...
# 397  Não se trata de censura, se trata de coibir di...
# 398  Dificil admitir q hj é um Grande Dia né minha ...
# 399  Esse tal de  acha que é DEUS. Duvido que ele a...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0                             A Sra curte uma censura?      1       0.033065
# 1    Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2       Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3           Saudade de uma censura, não é minha filha?      1       0.039592
# 4    Todo bom comunista comemora censura, depois sa...      1       0.043954
# ..                                                 ...    ...            ...
# 395  Só é censura quando atinge o deles Quando é do...      1       0.068635
# 396  Olha a ingenuidade. Quem é que vai censurar a ...      2       0.068722
# 397                             continua sendo censura      2       0.068751
# 398  Vamos ver quem vai comemorar a censura com “Gr...      0       0.068774
# 399  Vivi pra ver reacionário reclamando de censura...      0       0.068815
#
#      P(Conflict)  Conflict
# 0       0.966935         1
# 1       0.966084         1
# 2       0.961592         1
# 3       0.960408         1
# 4       0.956046         1
# ..           ...       ...
# 395     0.931365        -1
# 396     0.931278         1
# 397     0.931249         1
# 398     0.931226         1
# 399     0.931185         1
#
# [400 rows x 6 columns]

# %%
confusion = np.zeros((3,3))

idx_diff = []  # lista com os índices i onde as classificações diferem

# %%
for i in range(df_caio.shape[0]):
  caio = int(df_caio.iloc[i]["Conflict"])
  victor = int(df_victor.iloc[i]["Conflict"])

  # mapeia -1 para 2 para a matriz 3x3
  row = 2 if caio == -1 else caio
  col = 2 if victor == -1 else victor

  confusion[row][col] += 1

  # se são diferentes (fora da diagonal principal)
  if row != col:
    idx_diff.append(i)

# %%
confusion
# Out:
# array([[139.,  22.,   5.],
#        [  8., 218.,   0.],
#        [  3.,   3.,   2.]])

# %%
idx_diff
# Out:
# [10,
#  11,
#  15,
#  26,
#  28,
#  35,
#  47,
#  61,
#  62,
#  66,
#  67,
#  75,
#  80,
#  98,
#  102,
#  116,
#  119,
#  125,
#  131,
#  134,
#  135,
#  137,
#  151,
#  153,
#  178,
#  199,
#  216,
#  230,
#  252,
#  279,
#  288,
#  290,
#  326,
#  329,
#  343,
#  351,
#  366,
#  372,
#  381,
#  395,
#  396]

# %%
labels = ["0", "1", "-1"] # classes

plt.figure(figsize=(6,5))
sns.heatmap(confusion, annot=True, fmt=".0f", cmap="Blues", xticklabels=labels, yticklabels=labels) #desenha a matriz de confusão como uma "matriz de calor"

plt.xlabel("Predição Victor")
plt.ylabel("Predição Caio")
plt.title("Matriz de Confusão - Predição Pares")
plt.show()

# %%
mapa = {-1: "Indeterminado", 0: "Não Conflito", 1: "Conflito"}
mapa_tipo = {0: "Genérico", 1: "Reply", 2: "Quote"}

for i in range(len(idx_diff)):
  print("Tipo: ", mapa_tipo[int(df_caio.loc[idx_diff[i], "Class"])])
  print("Tweet 1: ", df_caio.loc[idx_diff[i], "tweet_1"])
  print("Tweet 2: ", df_caio.loc[idx_diff[i], "tweet_2"])
  print("Classificação Caio: ", mapa[int(df_caio.loc[idx_diff[i], "Conflict"])])
  print("Classificação Victor: ", mapa[int(df_victor.loc[idx_diff[i], "Conflict"])])
  print()
# Out:
# Tipo:  Reply
# Tweet 1:  Cês tão ligados que isso aqui é nível China de censura, né? Ou vão continuar achando normal e comemorando só porque prejudica a quem vocês não gostam?
# Tweet 2:  Quando a censura afeta quem eu não gosto, pode chamar de "justiça".
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  O que vc pensa de um edital de cultura com censura prévia? A prefeitura de Porto Alegre lançou edital p/ auxílio emergencial cultural q restringe a liberdade de expressão dos artistas, impondo como condição q o assunto não tenha cunho político ou religioso.
# Tweet 2:  Te decide, é a favor ou contra a censura.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Errado, se a lei disser que é proibido falar mal do presidente deixa de ser censura? Então não teve censura no regime militar?
# Tweet 2:  Acho que estamos em círculos aqui, Andi. Já voltei a me repetir quanto à diferença de censura e crime. Acho que não tenho mais nada a contibuir. Obrigada pela conversa.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  Já é hora, já passou da hora de acabar com esse inquérito inconstitucional, com ares de censura, que não soma nada -- só enxovalha mais o combalido Judiciário brasileiro.
# Tweet 2:  Quando o inquérito investiga só um lado dai é censura e não investigação
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  e as redes sociais ficaram um pouco menos odiosas...
# Tweet 2:  é censura do bem? é?
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  Para quem defendia a morte do presidente, defender a CENSURA é fichinha. Não querem apenas calar o Presidente e seus apoiadores, mas calar e se possível matar. Não lute hoje e amanhã você estará na VENEZUELA.
# Tweet 2:  Vc discorda DA MENSAGEM, NÃO do mensageiro. Porque
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  Censura contra a esquerda na ditadura militar: você criticava a ditadura e era morto  Censura atual: você fica 3 dias sem espalhar fakenews e xingar muito no twitter  Realmente é muita opressão contra blogueiros bolsonaristas
# Tweet 2:  Na verdade nem se deve comparar a ditadura militar com essa onda de censura pelo simples fato que vc tá vivo mesmo sem concordar
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  Branca chorando pq uma pessoa falou q preferia o cabelo dela grande, imagina se ela escutasse comentários como "bombril" "arbusto" "alisa" "prefiro de trança" "deu choque". Ela ia se matar no primeiro dia, ai esse povo da mt biscoito pra branco mimado acham q a vida é um morango.
# Tweet 2:  ah vai tomar no cu
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Pegue o exemplo do Roberto Jefferson: é um cidadão que vem cometendo seguidos crimes contra a honra de diversas pessoas. Deve ser processado e pode ser condenado no penal e no cível, mas não vejo previsão legal que justifique cercear o seu livre direito de expressão.
# Tweet 2:  O Roberto Jefferson não esta mentindo, ele fala c/ propriedade e sem medo. Não vejo crime como o sr. diz, muito longe disso.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Esse autoritarismo do Ministro Alexandre de Moraes vai ficar por isso mesmo?       Não defenderão a liberdade de expressão?
# Tweet 2:  odiamos censura mas só quando é pros nossos hehehehhe
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  ja agradeceram por serem jovens nessa geração e quando forem adultos não vão tratar os filhos de vcs assim?
# Tweet 2:  TW/// homofobia . . . . . . . . . . . esse video me da um gatilho tão grande, eu fiquei ontem o dia inteiro mal pq eu vi isso, dai vcs botam essa bosta na minha tml, pelo mesmo vcs avisem q nem eu fiz ali em cima.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Essa informação é falsa. A CPI da Lava Toga não tinha objeto delimitado, portanto, a alegação do jornalista em questão é fakenews.
# Tweet 2:  O cara é tão safado, e você percebe que ele adora uma censura quando ele faz publicação apenas pro próprio cercadinho, mas ditadores são os outros.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Quote
# Tweet 1:  Os censurados pelo Twitter hoje:  Roberto Jeffesson Allan dos Santos Bernardo Kuster Edson Salomão Rodrigo Ribeiro Sara Giromini Edgard Corona Luciano Hang Otavio Fakhoury Marcelo Stachin Reynaldo Bianchi Júnior
# Tweet 2:  Pelo twitter? O pássaro e vermelho mas teria essa coragem sozinho....
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  a cada dia mais certo de que este site é um grande delírio coletivo, 90% das discussões que a gente tem aqui não acontecem em nenhum outro lugar
# Tweet 2:  Ou você apoia o AI-5, ou você reclama da "Censura". Os dois não dá. Se não ficassem ameaçando, pregando violência gratuita... tavam de boa, quem não faz merda não paga. Só censurou quem não presta. Apologia tbm é crime kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Estou aberto aos argumentos jurídicos que mostram graves problemas na decisão do Alexandre de Moraes.  Dito isso, que perfis dedicados a fake news, ataques e assassinato de reputações sejam derrubados é algo que eu defenderia mesmo se fosse contra o meu lado político.
# Tweet 2:  Isso não  configura censura prévia?
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  O Twitter suspendeu 16 contas de bolsonaristas. Entre elas, as de Roberto Jefferson, dos blogueiros Allan dos Santos, Bernardo Küster e Sara Winter, dos empresários Luciano Hang, Edgard Corona e Otávio Fakhoury.
# Tweet 2:  Imaginem a gritaria que se faria se fossem contas de esquerdistas... censura, ditadura, fascismo, etc.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  Acrescento: se fosse eu o censurado, esses mesmos comemorariam e/ou criariam narrativas para encobrir/desmentir o fato. ACREDITE.  Alguns desses q perderam seus perfis assassinaram reputação de quem queria lava-toga, patrulham opiniões e promovem seu próprio mecanismo de censura.
# Tweet 2:  Eu esperava um: "Censura é inadmissível. Disto isto, são uns fdp, não nos gostamos etc...etc..."
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  É assim: ou você é contra a censura e a favor da democracia ou você defende AI-5 e pára de reclamar de censura ok? Os dois não dá,
# Tweet 2:  Olha a mente!
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Não a Censura!!! #naoacensura
# Tweet 2:  Hoje é um GRANDE DIA, sem dúvida alguma, mas alguém sabe dizer como vai a finada Bia Kicis?  É pro meu TCC  #QueimaQuengaral #GovernoDeFraudes
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  Esse homem enganou 81 senadores ao ser "sabatinado". Mentiu para a nação brasileira, para ter cargo vitalício no STF. Seu nome, Alexandre de Moraes.
# Tweet 2:  Mudou de idéia ou mentiu na cara dura?
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito
#
# Tipo:  Genérico
# Tweet 1:  Sabe o que vai acontecer se você só mudar o canal para falar mal do Alexandre de Moraes e não agir de fato? Ele vai mandar também encerrar sua conta de YouTube, o seu site e o que mais for preciso. Parem de perder tempo com asneiras, antes que não haja mais nada a fazer.
# Tweet 2:  Se o  não defende seus usuários contra abusos do judiciário,  talvez ele não merece s nossa presença nesta rede.  A empresa deveria acionar seu departamento jurídico diante da censura.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Quote
# Tweet 1:  Não há mais como alguém negar a realidade bem debaixo do nosso nariz: vivemos numa ditadura da toga suprema.
# Tweet 2:  Censura está literalmente estapeando sua cara enquanto você grita Bozo, Ele não e aquelas merdas inúteis de sempre.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Genérico
# Tweet 1:  Estamos provando um pouco do os chineses passam nas mãos do PCC. O que temos a fazer? Protestar, cobrar os parlamentares e, o governo.#VozParaBernardoKuster
# Tweet 2:  O povo está cego devido ao fundamentalismo religioso no país, por isso não percebe que  esse governo é um #GovernoDeFraudes
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Sobre contas de conservadores sendo banidas: a liberdade de expressão é direito fundamental garantido em nossa Constituição e deve ser válida para todos.
# Tweet 2:  Qual atitude  deputado vai tomar em relação a está censura? Estou lhe cobrando pois sou seu eleitor e apoiador a duas eleições.
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Quote
# Tweet 1:  Felipe Neto, que defende a censura e até a prisão de quem supostamente espalha "fake news", mais uma vez foi pego mentindo e propagando desinformação na internet. O sujeito mente tanto que, agora, teve que ser desmentido pelo embaixador da Ucrânia por mentir sobre aquele país.
# Tweet 2:  A bunda deve sentir inveja do tanto de merda que sai boca desse débil metal
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Quote
# Tweet 1:  Amigos aqui é Roberto Jefferson. Entrei na conta da minha filha para agradecer a todos pelo apoio. Em breve estaremos juntos novamente! Alexandre, não temo sua tirania!
# Tweet 2:  Deus é mais!
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Genérico
# Tweet 1:  foda q eu detesto todo esse antro bolsonarista, petista/psolista/pecedebista q existe nas redes sociais  posso comemorar qlqr remoção de conta assim como posso fzr piada com a morte do biroliro  pois sou cidadão comum e irrelevante  óbvio q o q aconteceu hj foi censura né porra
# Tweet 2:  Bolsominions, ou vcs pedem AI-5 ou reclamam da censura. Os dois não dá.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Na tela do Twitter no alto à esquerda tem três traços horizontais, clique em cima. Entre em  Conta e privacidade Clique em conta Depois clique em Dados e permissões Mude o local que está marcando Brasil para Estados Unidos. Pronto seu Twitter eatá nos EUA. Onde não há censura!
# Tweet 2:  Censura só é censura se acontece com quem pensa igual a vc, impressionante.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Já que está falando de censura, poderia fazer um post falando das investigações do Ministro da Justiça contra servidores que se auto intitulam antifascistas. Esse tipo de comportamento típico de governo fascista vc não condena, né?
# Tweet 2:  E esse tipo de censura??
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Genérico
# Tweet 1:  Será que o Alexandre de Moraes realmente acha que tá prejudicando o Bolsonaro com essa censura ? hahahahahahahahah esses cara vivem numa realidade paralela mesmo... 22 tá cada dia mais garantido
# Tweet 2:  ou você reclama de censura, ou você pede a volta da ditadura, os dois juntos n dá
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Entendi.... e reclama de censura ?!? Coerente.
# Tweet 2:  ....por quê querem fechar, mas.... Sua resposta poderia ser crime, Lei 7.170, de 1983, artigos 16 e 17, caso vc fizesse uma manifestação ameaçando o congresso e STF e/ou propagasse ofensas e ameaças. É isto que vc está chamando de censura....
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Vocês também estão sentindo que o clima aqui no Twitter deu uma melhorada?
# Tweet 2:  Grande dia, hoje está tudo melhor.  Inclusive o Jair Bolsonaro!!  Curado
# Classificação Caio:  Conflito
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  Pra vcs terem acesso aos meus tweets
# Tweet 2:  Vcs são um bando de idiotas mesmo! O capitão de vcs está abandonando todo mundo q o apoiou: Sérgio Moro, Bia Kicis, Allan dos Santos, Gn Santos Cruz, Sara extremista, Babiano, PSL....esse covarde é do tipo q abandona seus soldados feridos no campo de batalha, e foge + os filhos
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Quanto a censura do   na pessoa de   é fácil.NÃO VOTE EM NENHUM   candidato ligado aos senadores que aí estão.Covardes, não merecem essas vozes que não defendem o povo.
# Tweet 2:  censura não eh uma parada legal, mas censurar alguém q queria censura? por enquanto eu vou me preocupar tanto com a morte de alguém que quer o assassinato de inocentes.
# Classificação Caio:  Indeterminado
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  Censura não é, e nunca foi algo aceito pelos Anonymous, independente da forma que essa se apresenta, MAS, quem escolhe representante ao invés de se representar, bom, esse sim só aceita. Queira o sujeito ou não.  #NósSomosAnonymous #CadaVezMaisEnterradosNaMatrix #censura
# Tweet 2:  Os caras passam o dia inteiro destilando ódio e divulgando fake news e quer reclamar de "censura". Vai pro inferno.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  Gente que cria e espalha Fake News DEVEM ser censuradas na internet. Oras, não sabem usar de forma honesta!  Tem que perder a conta.
# Tweet 2:  Então... você só errou no fato de chamar censura quem cria fake news...  :)
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  aqueles que se diziam contra a censura meses atrás estão rindo hoje que país bosta hein
# Tweet 2:  censura só é ruim quando é com quem voce concorda né?
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Genérico
# Tweet 1:  A Galera do AI-5 reclamando de censura? É piada né??? Kkkkkk
# Tweet 2:  Se você configurar o Tweeter para dizer que seu país de origem não é o Brasil, não estará sujeito à censura aqui no Brasil.  Vá em: Configurações. Conta. País.  E troque para outro país! E reinicie o Twitter.
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito
#
# Tipo:  Reply
# Tweet 1:  "A censura pode se voltar contra você, o poder muda de mãos"  Tirando o fato de que, pra sorte de quem tá comemorando, o lado que tá sofrendo censura é democrático demais e nunca vai fazer nada do tipo ¯\_(ツ)_/¯
# Tweet 2:  A censura foi , é e será contra os denunciadores do mal.  Quem é do sistema não sofre censura.
# Classificação Caio:  Indeterminado
# Classificação Victor:  Não Conflito
#
# Tipo:  Reply
# Tweet 1:  A hipocrisia das pessoas que defendem censura numa rede social e inexplicável
# Tweet 2:  Só é censura quando atinge o deles Quando é dos outros ai é de boas, censura onde?
# Classificação Caio:  Não Conflito
# Classificação Victor:  Indeterminado
#
# Tipo:  Quote
# Tweet 1:  Me faltam adjetivos pra classificar a suspensão de contas em redes sociais APENAS de apoiadores do Governo.   Para os da esquerda que comemoram, lembrem-se que nada impede que isso aconteça com vocês a qualquer momento.   A censura é real.
# Tweet 2:  Olha a ingenuidade. Quem é que vai censurar a si mesmo? Me explica por favor
# Classificação Caio:  Não Conflito
# Classificação Victor:  Conflito

# %%
#CLASSIFICAÇÕES POR CLASSES CAIO
print("CLASSIFICAÇÕES POR CLASSES CAIO:")
print("contas suspensas:")
print("Conflito:", df_caio[df_caio['Conflict'] == 1].shape[0])
print("Não conflito:", df_caio[df_caio['Conflict'] == 0].shape[0])
print("Indeterminado:", df_caio[df_caio['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES CAIO:
# contas suspensas:
# Conflito: 226
# Não conflito: 166
# Indeterminado: 8

# %%
#CLASSIFICAÇÕES POR CLASSES VICTOR
print("CLASSIFICAÇÕES POR CLASSES VICTOR:")
print("contas suspensas:")
print("Conflito:", df_victor[df_victor['Conflict'] == 1].shape[0])
print("Não conflito:", df_victor[df_victor['Conflict'] == 0].shape[0])
print("Indeterminado:", df_victor[df_victor['Conflict'] == -1].shape[0])
# Out:
# CLASSIFICAÇÕES POR CLASSES VICTOR:
# contas suspensas:
# Conflito: 243
# Não conflito: 150
# Indeterminado: 7

# %%
#Distribuição de conflitos por classes CAIO

#Separando as classes
reply_caio = df_caio[df_caio['Class'] == 1]
quote_caio = df_caio[df_caio['Class'] == 2]
original_caio = df_caio[df_caio['Class'] == 0]
print("Distribuição de conflitos por classes CAIO:")
print("Replys anotados:", reply_caio.shape[0])
print("Conflitos:", reply_caio[reply_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_caio[reply_caio['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_caio.shape[0])
print("Conflitos:", quote_caio[quote_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_caio[quote_caio['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_caio.shape[0])
print("Conflitos:", original_caio[original_caio['Conflict'] == 1].shape[0])
print("Não conflitos:", original_caio[original_caio['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes CAIO:
# Replys anotados: 260
# Conflitos: 191
# Não conflitos: 67
#
# Quote anotados: 77
# Conflitos: 20
# Não conflitos: 52
#
# Originals anotados: 63
# Conflitos: 15
# Não conflitos: 47

# %%
#Distribuição de conflitos por classes VICTOR

#Separando as classes
reply_victor = df_victor[df_victor['Class'] == 1]
quote_victor = df_victor[df_victor['Class'] == 2]
original_victor = df_victor[df_victor['Class'] == 0]
print("Distribuição de conflitos por classes VICTOR:")
print("Replys anotados:", reply_victor.shape[0])
print("Conflitos:", reply_victor[reply_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", reply_victor[reply_victor['Conflict'] == 0].shape[0])
print()
print("Quote anotados:", quote_victor.shape[0])
print("Conflitos:", quote_victor[quote_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", quote_victor[quote_victor['Conflict'] == 0].shape[0])
print()
print("Originals anotados:", original_victor.shape[0])
print("Conflitos:", original_victor[original_victor['Conflict'] == 1].shape[0])
print("Não conflitos:", original_victor[original_victor['Conflict'] == 0].shape[0])
# Out:
# Distribuição de conflitos por classes VICTOR:
# Replys anotados: 260
# Conflitos: 191
# Não conflitos: 65
#
# Quote anotados: 77
# Conflitos: 25
# Não conflitos: 49
#
# Originals anotados: 63
# Conflitos: 27
# Não conflitos: 36

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_caio[reply_caio['Conflict'] == 1].shape[0],
    quote_caio[quote_caio['Conflict'] == 1].shape[0],
    original_caio[original_caio['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_caio[reply_caio['Conflict'] == 0].shape[0],
    quote_caio[quote_caio['Conflict'] == 0].shape[0],
    original_caio[original_caio['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_caio[reply_caio['Conflict'] == -1].shape[0],
    quote_caio[quote_caio['Conflict'] == -1].shape[0],
    original_caio[original_caio['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class CAIO")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# grafico
# Registando as contagens de classificações por estruturas
classes = ['Replys', 'quotes', 'Originals']

conflitos = [
    reply_victor[reply_victor['Conflict'] == 1].shape[0],
    quote_victor[quote_victor['Conflict'] == 1].shape[0],
    original_victor[original_victor['Conflict'] == 1].shape[0]
]

nao_conflitos = [
    reply_victor[reply_victor['Conflict'] == 0].shape[0],
    quote_victor[quote_victor['Conflict'] == 0].shape[0],
    original_victor[original_victor['Conflict'] == 0].shape[0]
]

indeterminados = [
    reply_victor[reply_victor['Conflict'] == -1].shape[0],
    quote_victor[quote_victor['Conflict'] == -1].shape[0],
    original_victor[original_victor['Conflict'] == -1].shape[0]
]



# Posição das barras

x = np.arange(len(classes))

largura = 0.25

#desenhando o grafico

plt.figure(figsize=(10,6))

plt.bar(x - largura, conflitos,
        width=largura,
        label='Conflito')

plt.bar(x, nao_conflitos,
        width=largura,
        label='Não conflito')

plt.bar(x + largura, indeterminados,
        width=largura,
        label='Indeterminado')

plt.xticks(x, classes)

plt.xlabel("Classes")
plt.ylabel("Quantidade")

plt.title("Distribuição de conflitos por class VICTOR")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# Previsoes incorretas CAIO:
df_inc_caio = df_caio[(df_caio['P(Conflict)'] > 0.5) & (df_caio['Conflict'] != 1)]
df_inc_caio.shape
# Out:
# (79, 6)

# %%
# Previsoes incorretas VICTOR:
df_inc_victor = df_victor[(df_victor['P(Conflict)'] > 0.5) & (df_victor['Conflict'] != 1)]
df_inc_victor.shape
# Out:
# (65, 6)

# %%
#Erros por classe de tweet CAIO
print("Erros por classe de tweet:")
print("Replys:", df_inc_caio[df_inc_caio['Class'] == 1].shape[0])
print("Quotes:", df_inc_caio[df_inc_caio['Class'] == 2].shape[0])
print("Originals:", df_inc_caio[df_inc_caio['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 44
# Quotes: 15
# Originals: 20

# %%
#Erros por classe de tweet VICTOR
print("Erros por classe de tweet:")
print("Replys:", df_inc_victor[df_inc_victor['Class'] == 1].shape[0])
print("Quotes:", df_inc_victor[df_inc_victor['Class'] == 2].shape[0])
print("Originals:", df_inc_victor[df_inc_victor['Class'] == 0].shape[0])
# Out:
# Erros por classe de tweet:
# Replys: 42
# Quotes: 11
# Originals: 12

# %%
#Organizando classificações de conflitos de Caio e Victor em um unico DF
df = df_caio.drop('Conflict', axis = 1)
df['Conflict_Caio'] = df_caio['Conflict']
df['Conflict_Victor'] = df_victor['Conflict']

# %%
df
# Out:
#                                                tweet_1  \
# 0    Vocês também estão sentindo que o clima aqui n...
# 1    Vocês também estão sentindo que o clima aqui n...
# 2    Vocês também estão sentindo que o clima aqui n...
# 3    Vocês também estão sentindo que o clima aqui n...
# 4    Vocês também estão sentindo que o clima aqui n...
# ..                                                 ...
# 395  A hipocrisia das pessoas que defendem censura ...
# 396  Me faltam adjetivos pra classificar a suspensã...
# 397  Não se trata de censura, se trata de coibir di...
# 398  Dificil admitir q hj é um Grande Dia né minha ...
# 399  Esse tal de  acha que é DEUS. Duvido que ele a...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0                             A Sra curte uma censura?      1       0.033065
# 1    Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2       Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3           Saudade de uma censura, não é minha filha?      1       0.039592
# 4    Todo bom comunista comemora censura, depois sa...      1       0.043954
# ..                                                 ...    ...            ...
# 395  Só é censura quando atinge o deles Quando é do...      1       0.068635
# 396  Olha a ingenuidade. Quem é que vai censurar a ...      2       0.068722
# 397                             continua sendo censura      2       0.068751
# 398  Vamos ver quem vai comemorar a censura com “Gr...      0       0.068774
# 399  Vivi pra ver reacionário reclamando de censura...      0       0.068815
#
#      P(Conflict)  Conflict_Caio  Conflict_Victor
# 0       0.966935              1                1
# 1       0.966084              1                1
# 2       0.961592              1                1
# 3       0.960408              1                1
# 4       0.956046              1                1
# ..           ...            ...              ...
# 395     0.931365              0               -1
# 396     0.931278              0                1
# 397     0.931249              1                1
# 398     0.931226              1                1
# 399     0.931185              1                1
#
# [400 rows x 7 columns]

# %%
df.to_csv("contas_suspensas_induzido_classificado.csv", index=False, encoding="utf-8")
files.download("contas_suspensas_induzido_classificado.csv")

# %% [markdown]
# # **Criando Dataset das divergencias**

# %%
div = df_caio.iloc[idx_diff].drop('Conflict', axis=1)
div['Conflict_caio'] = df_caio['Conflict'].iloc[idx_diff].astype(int)
div['Conflict_victor'] = df_victor['Conflict'].iloc[idx_diff].astype(int)
div['Conflict'] = np.nan

# %%
div.shape
# Out:
# (41, 8)

# %%
div
# Out:
#                                                tweet_1  \
# 10   Cês tão ligados que isso aqui é nível China de...
# 11   O que vc pensa de um edital de cultura com cen...
# 15   Errado, se a lei disser que é proibido falar m...
# 26   Já é hora, já passou da hora de acabar com ess...
# 28   e as redes sociais ficaram um pouco menos odio...
# 35   Para quem defendia a morte do presidente, defe...
# 47   Censura contra a esquerda na ditadura militar:...
# 61   Branca chorando pq uma pessoa falou q preferia...
# 62   Pegue o exemplo do Roberto Jefferson: é um cid...
# 66   Esse autoritarismo do Ministro Alexandre de Mo...
# 67   ja agradeceram por serem jovens nessa geração ...
# 75   Essa informação é falsa. A CPI da Lava Toga nã...
# 80   Os censurados pelo Twitter hoje:  Roberto Jeff...
# 98   a cada dia mais certo de que este site é um gr...
# 102  Estou aberto aos argumentos jurídicos que most...
# 116  O Twitter suspendeu 16 contas de bolsonaristas...
# 119  Acrescento: se fosse eu o censurado, esses mes...
# 125  É assim: ou você é contra a censura e a favor ...
# 131                      Não a Censura!!! #naoacensura
# 134  Esse homem enganou 81 senadores ao ser "sabati...
# 135  Sabe o que vai acontecer se você só mudar o ca...
# 137  Não há mais como alguém negar a realidade bem ...
# 151  Estamos provando um pouco do os chineses passa...
# 153  Sobre contas de conservadores sendo banidas: a...
# 178  Felipe Neto, que defende a censura e até a pri...
# 199  Amigos aqui é Roberto Jefferson. Entrei na con...
# 216  foda q eu detesto todo esse antro bolsonarista...
# 230  Na tela do Twitter no alto à esquerda tem três...
# 252  Já que está falando de censura, poderia fazer ...
# 279  Será que o Alexandre de Moraes realmente acha ...
# 288     Entendi.... e reclama de censura ?!? Coerente.
# 290  Vocês também estão sentindo que o clima aqui n...
# 326               Pra vcs terem acesso aos meus tweets
# 329  Quanto a censura do   na pessoa de   é fácil.N...
# 343  Censura não é, e nunca foi algo aceito pelos A...
# 351  Gente que cria e espalha Fake News DEVEM ser c...
# 366  aqueles que se diziam contra a censura meses a...
# 372  A Galera do AI-5 reclamando de censura? É piad...
# 381  "A censura pode se voltar contra você, o poder...
# 395  A hipocrisia das pessoas que defendem censura ...
# 396  Me faltam adjetivos pra classificar a suspensã...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 10   Quando a censura afeta quem eu não gosto, pode...      1       0.055252
# 11           Te decide, é a favor ou contra a censura.      1       0.062581
# 15   Acho que estamos em círculos aqui, Andi. Já vo...      1       0.073321
# 26   Quando o inquérito investiga só um lado dai é ...      1       0.117276
# 28                                é censura do bem? é?      2       0.121125
# 35   Vc discorda DA MENSAGEM, NÃO do mensageiro. Po...      2       0.145344
# 47   Na verdade nem se deve comparar a ditadura mil...      1       0.212322
# 61                                  ah vai tomar no cu      2       0.300295
# 62   O Roberto Jefferson não esta mentindo, ele fal...      1       0.307496
# 66   odiamos censura mas só quando é pros nossos he...      0       0.327721
# 67   TW/// homofobia . . . . . . . . . . . esse vid...      2       0.333758
# 75   O cara é tão safado, e você percebe que ele ad...      1       0.510169
# 80   Pelo twitter? O pássaro e vermelho mas teria e...      2       0.574343
# 98   Ou você apoia o AI-5, ou você reclama da "Cens...      0       0.694339
# 102                Isso não  configura censura prévia?      1       0.729819
# 116  Imaginem a gritaria que se faria se fossem con...      1       0.817937
# 119  Eu esperava um: "Censura é inadmissível. Disto...      1       0.832031
# 125                                      Olha a mente!      2       0.849150
# 131  Hoje é um GRANDE DIA, sem dúvida alguma, mas a...      0       0.858058
# 134             Mudou de idéia ou mentiu na cara dura?      2       0.865195
# 135  Se o  não defende seus usuários contra abusos ...      0       0.865899
# 137  Censura está literalmente estapeando sua cara ...      2       0.876961
# 151  O povo está cego devido ao fundamentalismo rel...      0       0.902064
# 153  Qual atitude  deputado vai tomar em relação a ...      1       0.905198
# 178  A bunda deve sentir inveja do tanto de merda q...      2       0.936853
# 199                                       Deus é mais!      2       0.946526
# 216  Bolsominions, ou vcs pedem AI-5 ou reclamam da...      0       0.058278
# 230  Censura só é censura se acontece com quem pens...      0       0.059438
# 252                           E esse tipo de censura??      1       0.060455
# 279  ou você reclama de censura, ou você pede a vol...      0       0.061913
# 288  ....por quê querem fechar, mas.... Sua respost...      1       0.062387
# 290  Grande dia, hoje está tudo melhor.  Inclusive ...      1       0.062447
# 326  Vcs são um bando de idiotas mesmo! O capitão d...      1       0.063989
# 329  censura não eh uma parada legal, mas censurar ...      0       0.064543
# 343  Os caras passam o dia inteiro destilando ódio ...      0       0.065544
# 351  Então... você só errou no fato de chamar censu...      1       0.066076
# 366  censura só é ruim quando é com quem voce conco...      0       0.066874
# 372  Se você configurar o Tweeter para dizer que se...      0       0.067508
# 381  A censura foi , é e será contra os denunciador...      1       0.068222
# 395  Só é censura quando atinge o deles Quando é do...      1       0.068635
# 396  Olha a ingenuidade. Quem é que vai censurar a ...      2       0.068722
#
#      P(Conflict)  Conflict_caio  Conflict_victor  Conflict
# 10      0.944748              1                0       NaN
# 11      0.937419              0                1       NaN
# 15      0.926680              1                0       NaN
# 26      0.882724              0                1       NaN
# 28      0.878875              0                1       NaN
# 35      0.854656             -1                0       NaN
# 47      0.787678              1                0       NaN
# 61      0.699705             -1                1       NaN
# 62      0.692504              0                1       NaN
# 66      0.672279              0                1       NaN
# 67      0.666242              0                1       NaN
# 75      0.489831              0               -1       NaN
# 80      0.425657              0                1       NaN
# 98      0.305661              0                1       NaN
# 102     0.270180              1                0       NaN
# 116     0.182063              1                0       NaN
# 119     0.167968              0                1       NaN
# 125     0.150850             -1                1       NaN
# 131     0.141942              0                1       NaN
# 134     0.134805             -1                0       NaN
# 135     0.134101              0                1       NaN
# 137     0.123039              1                0       NaN
# 151     0.097936              0                1       NaN
# 153     0.094802              1                0       NaN
# 178     0.063147              0               -1       NaN
# 199     0.053474              0               -1       NaN
# 216     0.941722              0                1       NaN
# 230     0.940562              0                1       NaN
# 252     0.939545              0               -1       NaN
# 279     0.938087              0                1       NaN
# 288     0.937613              0                1       NaN
# 290     0.937553              1                0       NaN
# 326     0.936011              0                1       NaN
# 329     0.935457             -1                1       NaN
# 343     0.934456              0                1       NaN
# 351     0.933924              0                1       NaN
# 366     0.933126              0                1       NaN
# 372     0.932492              0                1       NaN
# 381     0.931778             -1                0       NaN
# 395     0.931365              0               -1       NaN
# 396     0.931278              0                1       NaN

# %%
div_aborto_final = div.drop(columns=['Conflict_caio', 'Conflict_victor'])
div_aborto_final
# Out:
#                                                tweet_1  \
# 10   Cês tão ligados que isso aqui é nível China de...
# 11   O que vc pensa de um edital de cultura com cen...
# 15   Errado, se a lei disser que é proibido falar m...
# 26   Já é hora, já passou da hora de acabar com ess...
# 28   e as redes sociais ficaram um pouco menos odio...
# 35   Para quem defendia a morte do presidente, defe...
# 47   Censura contra a esquerda na ditadura militar:...
# 61   Branca chorando pq uma pessoa falou q preferia...
# 62   Pegue o exemplo do Roberto Jefferson: é um cid...
# 66   Esse autoritarismo do Ministro Alexandre de Mo...
# 67   ja agradeceram por serem jovens nessa geração ...
# 75   Essa informação é falsa. A CPI da Lava Toga nã...
# 80   Os censurados pelo Twitter hoje:  Roberto Jeff...
# 98   a cada dia mais certo de que este site é um gr...
# 102  Estou aberto aos argumentos jurídicos que most...
# 116  O Twitter suspendeu 16 contas de bolsonaristas...
# 119  Acrescento: se fosse eu o censurado, esses mes...
# 125  É assim: ou você é contra a censura e a favor ...
# 131                      Não a Censura!!! #naoacensura
# 134  Esse homem enganou 81 senadores ao ser "sabati...
# 135  Sabe o que vai acontecer se você só mudar o ca...
# 137  Não há mais como alguém negar a realidade bem ...
# 151  Estamos provando um pouco do os chineses passa...
# 153  Sobre contas de conservadores sendo banidas: a...
# 178  Felipe Neto, que defende a censura e até a pri...
# 199  Amigos aqui é Roberto Jefferson. Entrei na con...
# 216  foda q eu detesto todo esse antro bolsonarista...
# 230  Na tela do Twitter no alto à esquerda tem três...
# 252  Já que está falando de censura, poderia fazer ...
# 279  Será que o Alexandre de Moraes realmente acha ...
# 288     Entendi.... e reclama de censura ?!? Coerente.
# 290  Vocês também estão sentindo que o clima aqui n...
# 326               Pra vcs terem acesso aos meus tweets
# 329  Quanto a censura do   na pessoa de   é fácil.N...
# 343  Censura não é, e nunca foi algo aceito pelos A...
# 351  Gente que cria e espalha Fake News DEVEM ser c...
# 366  aqueles que se diziam contra a censura meses a...
# 372  A Galera do AI-5 reclamando de censura? É piad...
# 381  "A censura pode se voltar contra você, o poder...
# 395  A hipocrisia das pessoas que defendem censura ...
# 396  Me faltam adjetivos pra classificar a suspensã...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 10   Quando a censura afeta quem eu não gosto, pode...      1       0.055252
# 11           Te decide, é a favor ou contra a censura.      1       0.062581
# 15   Acho que estamos em círculos aqui, Andi. Já vo...      1       0.073321
# 26   Quando o inquérito investiga só um lado dai é ...      1       0.117276
# 28                                é censura do bem? é?      2       0.121125
# 35   Vc discorda DA MENSAGEM, NÃO do mensageiro. Po...      2       0.145344
# 47   Na verdade nem se deve comparar a ditadura mil...      1       0.212322
# 61                                  ah vai tomar no cu      2       0.300295
# 62   O Roberto Jefferson não esta mentindo, ele fal...      1       0.307496
# 66   odiamos censura mas só quando é pros nossos he...      0       0.327721
# 67   TW/// homofobia . . . . . . . . . . . esse vid...      2       0.333758
# 75   O cara é tão safado, e você percebe que ele ad...      1       0.510169
# 80   Pelo twitter? O pássaro e vermelho mas teria e...      2       0.574343
# 98   Ou você apoia o AI-5, ou você reclama da "Cens...      0       0.694339
# 102                Isso não  configura censura prévia?      1       0.729819
# 116  Imaginem a gritaria que se faria se fossem con...      1       0.817937
# 119  Eu esperava um: "Censura é inadmissível. Disto...      1       0.832031
# 125                                      Olha a mente!      2       0.849150
# 131  Hoje é um GRANDE DIA, sem dúvida alguma, mas a...      0       0.858058
# 134             Mudou de idéia ou mentiu na cara dura?      2       0.865195
# 135  Se o  não defende seus usuários contra abusos ...      0       0.865899
# 137  Censura está literalmente estapeando sua cara ...      2       0.876961
# 151  O povo está cego devido ao fundamentalismo rel...      0       0.902064
# 153  Qual atitude  deputado vai tomar em relação a ...      1       0.905198
# 178  A bunda deve sentir inveja do tanto de merda q...      2       0.936853
# 199                                       Deus é mais!      2       0.946526
# 216  Bolsominions, ou vcs pedem AI-5 ou reclamam da...      0       0.058278
# 230  Censura só é censura se acontece com quem pens...      0       0.059438
# 252                           E esse tipo de censura??      1       0.060455
# 279  ou você reclama de censura, ou você pede a vol...      0       0.061913
# 288  ....por quê querem fechar, mas.... Sua respost...      1       0.062387
# 290  Grande dia, hoje está tudo melhor.  Inclusive ...      1       0.062447
# 326  Vcs são um bando de idiotas mesmo! O capitão d...      1       0.063989
# 329  censura não eh uma parada legal, mas censurar ...      0       0.064543
# 343  Os caras passam o dia inteiro destilando ódio ...      0       0.065544
# 351  Então... você só errou no fato de chamar censu...      1       0.066076
# 366  censura só é ruim quando é com quem voce conco...      0       0.066874
# 372  Se você configurar o Tweeter para dizer que se...      0       0.067508
# 381  A censura foi , é e será contra os denunciador...      1       0.068222
# 395  Só é censura quando atinge o deles Quando é do...      1       0.068635
# 396  Olha a ingenuidade. Quem é que vai censurar a ...      2       0.068722
#
#      P(Conflict)  Conflict
# 10      0.944748       NaN
# 11      0.937419       NaN
# 15      0.926680       NaN
# 26      0.882724       NaN
# 28      0.878875       NaN
# 35      0.854656       NaN
# 47      0.787678       NaN
# 61      0.699705       NaN
# 62      0.692504       NaN
# 66      0.672279       NaN
# 67      0.666242       NaN
# 75      0.489831       NaN
# 80      0.425657       NaN
# 98      0.305661       NaN
# 102     0.270180       NaN
# 116     0.182063       NaN
# 119     0.167968       NaN
# 125     0.150850       NaN
# 131     0.141942       NaN
# 134     0.134805       NaN
# 135     0.134101       NaN
# 137     0.123039       NaN
# 151     0.097936       NaN
# 153     0.094802       NaN
# 178     0.063147       NaN
# 199     0.053474       NaN
# 216     0.941722       NaN
# 230     0.940562       NaN
# 252     0.939545       NaN
# 279     0.938087       NaN
# 288     0.937613       NaN
# 290     0.937553       NaN
# 326     0.936011       NaN
# 329     0.935457       NaN
# 343     0.934456       NaN
# 351     0.933924       NaN
# 366     0.933126       NaN
# 372     0.932492       NaN
# 381     0.931778       NaN
# 395     0.931365       NaN
# 396     0.931278       NaN

# %%
div_aborto_final.to_csv("divergencias_contas_suspensas_induzido.csv", index=False, encoding="utf-8")
files.download("divergencias_contas_suspensas_induzido.csv")

# %% [markdown]
# # **Criando Dataset das Convergencias**

# %%
conv_aborto = df_caio.drop(index=idx_diff, errors='ignore')
conv_aborto.shape
# Out:
# (359, 6)

# %%
conv_aborto
# Out:
#                                                tweet_1  \
# 0    Vocês também estão sentindo que o clima aqui n...
# 1    Vocês também estão sentindo que o clima aqui n...
# 2    Vocês também estão sentindo que o clima aqui n...
# 3    Vocês também estão sentindo que o clima aqui n...
# 4    Vocês também estão sentindo que o clima aqui n...
# ..                                                 ...
# 393   É  censura pura e simples . Isso é uma vergonha.
# 394  Proibir, com ordem prévia e geral, que uma pes...
# 397  Não se trata de censura, se trata de coibir di...
# 398  Dificil admitir q hj é um Grande Dia né minha ...
# 399  Esse tal de  acha que é DEUS. Duvido que ele a...
#
#                                                tweet_2  Class  P(NoConflict)  \
# 0                             A Sra curte uma censura?      1       0.033065
# 1    Um dia pode ser a sua conta bloqueada, quero v...      1       0.033916
# 2       Pra tu que ama uma ditadura,é um grande dia...      1       0.038408
# 3           Saudade de uma censura, não é minha filha?      1       0.039592
# 4    Todo bom comunista comemora censura, depois sa...      1       0.043954
# ..                                                 ...    ...            ...
# 393  Punição por espalharem mentiras não caracteriz...      1       0.068575
# 394  Quando proibiram a Folha de entrevistar o Lula...      1       0.068595
# 397                             continua sendo censura      2       0.068751
# 398  Vamos ver quem vai comemorar a censura com “Gr...      0       0.068774
# 399  Vivi pra ver reacionário reclamando de censura...      0       0.068815
#
#      P(Conflict)  Conflict
# 0       0.966935         1
# 1       0.966084         1
# 2       0.961592         1
# 3       0.960408         1
# 4       0.956046         1
# ..           ...       ...
# 393     0.931425         1
# 394     0.931405         1
# 397     0.931249         1
# 398     0.931226         1
# 399     0.931185         1
#
# [359 rows x 6 columns]

# %%
#juntando anotações do professor (QUANDO ELE ANOTAR)
#adicionando as classificações do professor
# file_class_prof = "1FSUrpSaiBAp5Gho-CsEw6kse3q4wCB8B"
# url = f"https://drive.google.com/uc?id={file_class_prof}"
# gdown.download(url, "class_prof.csv", quiet=False)
# df_class_prof = pd.read_csv ("class_prof.csv")

# %%
# df_class_prof

# %%
# df_desempate = div.iloc[:len(df_class_prof)-1,:]
# df_desempate

# %%
# df_desempate['Conflict_prof'] = df_class_prof['Conflict']
# df_desempate

# %%
# def resolver_conflito(row):
#     prof = row['Conflict_prof']
#     caio = row['Conflict_caio']
#     victor = row['Conflict_victor']

#     if prof == caio or prof == victor:
#         return prof
#     else:
#         return -1

# df_desempate['Conflict'] = df_desempate.apply(resolver_conflito, axis=1)

# %%
# df_desempate = df_desempate.drop(columns=['Conflict_caio', 'Conflict_victor', 'Conflict_prof'])
# df_desempate

# %%
# conv_aborto = pd.concat([conv_aborto, df_desempate], ignore_index=True, axis = 0)
# conv_aborto

# %%
conv_aborto.to_csv("convergencias_contas_suspensas_induzido.csv", index=False, encoding="utf-8")
files.download("convergencias_contas_suspensas_induzido.csv")

# %% [markdown]
# # **Criando dataset dos não anotados**

# %%
df_remaining
# Out:
#                                                  tweet_1  \
# 400    Proibir, com ordem prévia e geral, que uma pes...
# 401    Alguém avisa para ele que é censura!? Analfabe...
# 402    Vocês também estão sentindo que o clima aqui n...
# 403    Vocês também estão sentindo que o clima aqui n...
# 404    por não ter resposta eu sou toda hora, agr rec...
# ...                                                  ...
# 30660  Os censurados amanhã podem ser eu e você!  #Vo...
# 30661  #STFVergonhaNacional Alexandre Garcia: Brasil ...
# 30662  SEXTA-FEIRA DA VERGONHA Alexandre de Moraes ma...
# 30663  Os censurados amanhã podem ser eu e você!  #Vo...
# 30664  Comigo funcionou, perfis censurados pelo tiran...
#
#                                                  tweet_2  Class  \
# 400    E se essa pessoa recebe para destruir reputaçõ...      1
# 401    Tá batendo boca comigo até agora jurando que n...      1
# 402    Quem diria que seria a própria oposição través...      2
# 403                           Comunista gosta de censura      1
# 404    que historia de censura victor na hora q eu di...      1
# ...                                                  ...    ...
# 30660  Os censurados amanhã podem ser eu e você!  #ST...      2
# 30661  Contas conservadoras sendo suspensas simultane...      0
# 30662       STF VERGONHA NACIONAL #VozParaBernardoKuster      2
# 30663  Cuiďado. Os censurados amanhã podem ser eu e v...      2
# 30664  Comigo funcionou, perfis censurados pelo tiran...      2
#
#        P(NoConflict)  P(Conflict)  Conflict
# 400         0.068839     0.931161       NaN
# 401         0.068840     0.931161       NaN
# 402         0.068913     0.931087       NaN
# 403         0.068989     0.931011       NaN
# 404         0.069060     0.930940       NaN
# ...              ...          ...       ...
# 30660       0.995996     0.004004       NaN
# 30661       0.996057     0.003943       NaN
# 30662       0.996067     0.003933       NaN
# 30663       0.996080     0.003920       NaN
# 30664       0.996087     0.003913       NaN
#
# [30265 rows x 6 columns]

# %%
df_remaining.to_csv("nao_anotados_contas_suspensas_induzido.csv", index=False, encoding="utf-8")
files.download("nao_anotados_contas_suspensas_induzido.csv")
